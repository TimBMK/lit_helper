# %% [markdown]
# # A number of tests for retrieval

# %%
import langchain_ollama
import os

from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain.chains import RetrievalQA

from langchain_core.prompts import PromptTemplate

# %%
# set model
# run ollama serve for local API instance
# currently running llama 3.2 3b for the chat
# nomic-embed-text for the embeddings - this model is faster than the llama emebddings and retrieves better results
embeddings = langchain_ollama.OllamaEmbeddings(model = "nomic-embed-text")

llm = langchain_ollama.ChatOllama(
    model = "llama3.2",
    temperature = 0.0,
    num_predict = 512, # max number of tokens to generate
    )

# %% [markdown]
# ## Set up  the Vectorstore Retriever

# %%
# check if the folder db_directory already exists. If not, creat it and load the documents into the vector store. Else, use the existing vector store. Makes a new DB for shortened docs

lit_directory = "./test_data/" # directory with literature to load for the RAG

db_directory = "./test_chroma_db" # directory to save the vector store

pattern = r"[^\\/]*[\\/](?P<author>.+?) (?P<year>\d{4}) (?P<title>.+)\.pdf" # regex pattern to extract metadata from naming scheme in literature directory. Adjust as needed!

short_docs = True # shorten document from pages to chunks? (set chunk size below)

docs_returned = 6 # number of docs returned by the retriever(s)

retriever_type = "mmr" # "similarity"  or "mmr"

if short_docs:
    db_directory += "_short"

if not os.path.exists(db_directory):
    # load documents
    loader = PyPDFDirectoryLoader(lit_directory)
    docs = loader.load() # metadata tracks paper and page number; each page is a single document

    # extract metadata from file names (according to the pattern specified above)
    docs = [
        Document(
            doc.page_content,
            metadata={
                **doc.metadata,
                **({
                    "author": metadata.group("author"),
                    "year": metadata.group("year"),
                    "title": metadata.group("title")
                } if (metadata := match(pattern, doc.metadata["source"])) else {})
            }
        )
        for doc in docs
    ]


    # optional step: split the docs into smaller chunks to fit into context window of the model (model dependant, necessary for small models) -!! test this, shorter chunks may lead to bad retrieval results !!-
    #           potential remedy: use whole pages, but use the model to summarise each page before chaining it into the context
    if short_docs:
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,  # chunk size (characters)
            chunk_overlap=200,  # chunk overlap (characters)
            add_start_index=True,  # track index in original document
            )
        
        docs = text_splitter.split_documents(docs)

    # make doc vector store. as the vector store can get quite large (and takes time to initialize in memory), we use a chroma database to store the vectors    
    vector_store = Chroma(
        collection_name="lit_helper_test",
        embedding_function=embeddings,
        persist_directory=db_directory,  # save data locally
        )
    
    vector_store.add_documents(docs) # add docs

else:
    vector_store = Chroma(
        collection_name="lit_helper_test",
        embedding_function=embeddings,
        persist_directory=db_directory,  # save data locally
    )


# turn the vector store into retriever(s)

if retriever_type == "mmr":
    retriever = vector_store.as_retriever(
        search_type="mmr", # MMR (Maximal Marginal Relevance) aims to diversify search results. the amount of diversification is set via the lambda_mult parameter
        search_kwargs={"k": docs_returned, # make sure the number of documents passed (k) fits into the context window
                       "fetch_k": docs_returned * 5, # could be adjusted, potentially run tests
                       "lambda_mult": 0.8 # amount of diversification, with 0 being maximum diversity
                       }, 
    )

if retriever_type == "similarity":
    retriever = vector_store.as_retriever(
        search_type="similarity", # similarity score; optionally with threshold ("similarity_score_threshold" with "score_threshold" kwarg)
        search_kwargs={"k": docs_returned}, # make sure the number of documents passed (k) fits into the context window
    )

# %%
# test the retriever
for doc in retriever.invoke("Habermas"):
    print(f'{doc.metadata["source"]} p.{doc.metadata["page"]}:\n{doc.page_content} \n\n')
# Out:
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.1:
# Rethinking the Public Sphere:
# A Contribution to the Critique of Actually Existing
# Democracy'
# NANCY FRASER
# Introduction
# Today in the U.S. we hear a great deal of ballyhoo about "the triumph of
# liberal democracy" and even "the end of history." Yet there is still a great
# deal to object to in our own "actually existing democracy," and the project
# of a critical social theory of the limits of democracy in late capitalist
# societies remains as relevant as ever. In fact, this project seems to me to
# have acquired a new urgency at a time when "liberal democracy" is being
# touted as the ne plus ultra of social systems for countries that are emerg-
# ing from Soviet-style state socialism, Latin American military dictator-
# ships, and southern African regimes of racial domination.
# Those of us who remain committed to theorizing the limits of democ-
# racy in late capitalist societies will find in the work of Jiirgen Habermas
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.10:
# contemporary public arena introduces new actors and new tensions between
# states, companies, and publics. A more differentiated view of grouping coun-
# tries with shared conditions is needed, as is a more dynamic view of the
# continuous competition for inﬂuence among states and their civil societies,
# including in various macro-regions (Mann 1986; 2013; Mann & Riley 2006).
# Thus we focus less on eternal system-level conditions but instead on the
# transformations of the structures that constitute the public arena.
# New Media Infrastructures and Their Impact on the Public Arena
# Media infrastructures provide three functions in the public arena. They
# produce information that societies need to pursue the public good. This
# includes the coverage of events, actors, and societal conditions but also
# extends to a role as“watchdogs” by critically covering elites, institutions,
# and groups. They alsodistribute information by providing audiences access
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.78:
# Sehl, A., Simon, F. M., and Schroeder, R. (2020). The Populist Campaigns
# against European Public Service Media: Hot Air or Existential Threat?
# International Communication Gazette.
# Settle, J. E. (2018). Frenemies: How Social Media Polarizes America .
# Cambridge: Cambridge University Press.
# Shoemaker, P. J., and Reese, S. D. (2014).Mediating the Message in the 21st
# Century, 3rd ed. New York: Routledge.
# Shoemaker, P. J., and V os, T. P. (2009).Gatekeeping Theory. New York:
# Routledge.
# Sides, J., Tesler, M., and Vavreck, L. (2018). Identity Crisis: The 2016
# Presidential Campaign and the Battle for the Meaning of America .
# Princeton, NJ: Princeton University Press.
# Skocpol, T., and Tervo, C. (Eds.). (2020). Upending American Politics:
# Polarizing Parties, Ideological Elites, and Citizen Activists from the Tea
# Party to the Anti-Trump Resistance. New York: Oxford University Press.
# Slater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.74:
# https://correctiv.org/aktuelles/neue-rechte/2017/01/04/russische-propaganda
# -fuer-deutsche-zuschauer/
# Konieczna, M. (2018). Journalism without Proﬁt: Making News When the
# Market Fails. Oxford: Oxford University Press.
# Kostka, G. (2019). China ’s Social Credit Systems and Public Opinion:
# Explaining High Levels of Approval.New Media & Society, 21(7), 1565–93.
# Kovach, B., and Rosenstiel, T. (2021).The Elements of Journalism: What
# Newspeople Should Know and the Public Should Expect , 4th ed.
# New York: The Crown Publishing Group.
# Kovic, M., Rauch ﬂeisch, A., Sele, M., and Caspar, C. (2018). Digital
# Astroturﬁng in Politics: De ﬁnition, Typology, and Countermeasures.
# Studies in Communication Sciences, 18(1), 69–85.
# Kuhn, R., and Nielsen, R. K., eds. (2014).Political Journalism in Transition:
# Western Europe in a Comparative Perspective. London: I. B. Tauris.
# Levin, Y . (2020).A Time to Build: From Family and Community to Congress
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.25:
# duality is also where China and the rest of the world meet, on the geopolitical
# level of macro-regions (Mann 1986; 2013; Mann & Riley 2006), in seeking
# leadership in the competition for digital infrastructure development and mar-
# kets, both for production and distribution, and consumption. Geopolitical com-
# petition, in turn, affects China’s domestic economy, though the main effect on
# politics has been to rally Chinese public opinion to cry foul play by the West and
# to champion the efforts of its domestic technology companies.
# In sum, China’s segmented and siloed public arena is controlled by the party-
# state. This keeps attention, reach, and visibility compartmentalized and man-
# aged. This constellation reﬂects the tensions of an authoritarian party-state that
# must maintain legitimacy as an expanding foreign power and amidst globalizing
# markets, as well as keep the lid on an unruly domestic civil society.
# Fractions around a Public Service Centre: Germany
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.25:
# that draw on concepts of mdtissage, see Gloria Anzaldda, Borderlands: La Frontera (1987) and
# Frangoise Lionnet, Autobiographical Voices: Race, Gender, Self-Portraiture (Ithaca NY: Comell
# University Press, 1989).
# 29. In these respects, the concept of a public differs from that of a community. "Community" suggests a bounded and fairly homogeneous group, and it often connotes consensus. "Public," in contrast,
# emphasizes discursive interaction that is in principle unbounded and open-ended, and this in turn
# implies a plurality of perspectives. Thus, the idea of a public, better than that of a community, can
# accommodate internal differences, antagonisms, and debates. For an account of the connection between
# publicity and plurality, see Hannah Arendt, The Human Condition (Chicago: The University of Chicago
# Press, 1958). For a critique of the concept of community, see Iris Young, "The Ideal of Community and

# %%
# test the retriever
for doc in retriever.invoke("What is the definition of the public sphere?"):
    print(f'{doc.metadata["source"]} p.{doc.metadata["page"]}:\n{doc.page_content} \n\n')
# Out:
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.4:
# Nancy Fraser 59
# Thus, at one level, the idea of the public sphere designated an institu-
# tional mechanism for "rationalizing" political domination by rendering
# states accountable to (some of) the citizenry. At another level, it desig-
# nated a specific kind of discursive interaction. Here the public sphere
# connoted an ideal of unrestricted rational discussion of public matters.
# The discussion was to be open and accessible to all; merely private
# interests were to be inadmissible; inequalities of status were to be brack-
# eted; and discussants were to deliberate as peers. The result of such
# discussion would be "public opinion" in the strong sense of a consensus
# about the common good.
# According to Habermas, the full utopian potential of the bourgeois
# conception of the public sphere was never realized in practice. The claim
# to open access in particular was not made good. Moreover, the bourgeois
# conception of the public sphere was premised on a social order in which
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.23:
# institutionalization of democratic interaction. Moreover, as Habermas has himself often pointed out,
# even in existing class societies, the significance of the public sphere is not entirely exhausted by its
# class function. On the contrary, the idea of the public sphere also functions here and now as a normnn of
# democratic interaction we use to criticize the limitations of actually existing public spheres. The point
# This content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM
# All use subject to JSTOR Terms and Conditions
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.3:
# scribes it, which this newer historiography renders suspect. Next, in the
# following four sections, I shall examine each of these assumptions in turn.
# Finally, in a brief conclusion, I shall draw together some strands from
# these critical discussions that point toward an alternative, post-bourgeois
# conception of the public sphere.
# The public sphere: Alternative histories, competing conceptions
# Let me begin by sketching some highlights of Habermas's account of the
# structural transformation of the public sphere. According to Habermas,
# the idea of a public sphere is that of a body of "private persons" assem-
# bled to discuss matters of "public concern" or "common interest." This
# idea acquired force and reality in early modern Europe in the constitution
# of "bourgeois publics spheres" as counterweights to absolutist states.
# These publics aimed to mediate between "society" and the state by hold-
# ing the state accountable to "society" via "publicity." At first this meant
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.2:
# struggles to deprivatize housework and child care are equated with their
# commodification. In both these cases, the result is to occlude the question
# whether to subject gender issues to the logic of the market or the admin-
# istrative state is to promote the liberation of women.
# The idea of "the public sphere" in Habermas's sense is a conceptual
# resource that can help overcome such problems. It designates a theater in
# modern societies in which political participation is enacted through the
# medium of talk. It is the space in which citizens deliberate about their
# common affairs, hence, an institutionalized arena of discursive interac-
# tion. This arena is conceptually distinct from the state; it a site for the
# production and circulation of discourses that can in principle be critical
# of the state. The public sphere in Habermas's sense is also conceptually
# distinct from the official-economy; it is not an arena of market relations
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.15:
# One important object of such interpublic contestation is the appropriate
# boundaries of the public sphere. Here the central questions are, what
# counts as a public matter and what, in contrast, is private? This brings me
# to a third set of problematic assumptions underlying the bourgeois con-
# ception of the public sphere, namely, assumptions concerning the appro-
# priate scope of publicity in relation to privacy.
# Let me remind you that it is central to Habermas's account that the
# bourgeois public sphere was to be a discursive arena in which "private
# persons" deliberated about "public matters." There are several different
# This content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM
# All use subject to JSTOR Terms and Conditions
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.21:
# 76 Rethinking the Public Sphere
# places, child care centers, or residential communities, for example, inter-
# nal institutional public spheres could be arenas both of opinion formation
# and decision-making. This would be tantamount to constituting sites of
# direct or quasi-direct democracy wherein all those engaged in a collective
# undertaking would participate in deliberations to determine its design and
# operation." However, this would still leave open the relationship between
# such internal public spheres-cum-decision-making-bodies and those ex-
# ternal publics to which they might also be deemed accountable. The
# question of that relationship becomes important when we consider that
# people who are affected by an undertaking in which they do not directly
# participate as agents may nonetheless have a stake in its modus operandi;
# they therefore also have a legitimate claim to a say, through some other
# (weaker or stronger) public sphere, in its institutional design and opera-
# tion.

# %%
len(retriever.invoke("Habermas")[0].page_content)
# Out:
# 4646

# %% [markdown]
# ## Build a RAG Chain

# %%
template = """You are a helpful assistant for finding relevant text passages in scientific literature. 
Use the following pieces of retrieved context to answer the question. Each piece of content starts with the indicators "Source" and "Page". Always provide these in your answer when using one of the retrieved passages.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}

Helpful answer:"""

rag_prompt = PromptTemplate.from_template(template)

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict


class State(TypedDict):
    question: str
    context: List[Document]
    answer: str
    prompt: str


def retrieve(state: State):
    retrieved_docs = retriever.invoke(state["question"])
    return {"context": retrieved_docs}
    

def generate(state: State):
    docs_content = "\n\n".join(f'Source: {doc.metadata["source"]}\nPage:{doc.metadata["page"]}\n{doc.page_content}' for doc in state["context"])
    messages = rag_prompt.invoke({"question": state["question"], "context": docs_content})
    response = llm.invoke(messages)
    return {"answer": response.content,
            "prompt": messages} # return the prompt for debugging purposes

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
q = "What is the definition of the public sphere?"

result = graph.invoke({"question": q})

for doc in result["context"]:
    print(f'{doc.metadata["source"]} p.{doc.metadata["page"]}:\n{doc.page_content} \n\n')

print(f'Answer: {result["answer"]}')
# Out:
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.14:
# Dahlberg L (2001a) Democracy via cyberspace: Examining the rhetorics and practices of three
# prominent camps. New Media & Society 3(2): 187–207.
# Dahlberg L (2001b) The internet and democratic discourse: Exploring the prospects of online
# deliberative forums extending the public sphere. Information, Communication & Society 4(4):
# 615–633.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.15:
# Graham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere.
# Doctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.
# Habermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1,
# Reason and the Rationalization of Society). Boston, MA: Beacon Press.
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.78:
# Party to the Anti-Trump Resistance. New York: Oxford University Press.
# Slater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and
# Democratization in Developmental Asia. Perspectives on Politics, 11(3),
# 717–33.
# Smith, R. M., and King, D. (2020). White Protectionism in America.
# Perspectives on Politics, 19(2), 460–78.
# Sobieraj, S. (2020).Credible Threat: Attacks against Women Online and the
# Future of Democracy. Oxford: Oxford University Press.
# Stier, S., Kirkizh, N., Froio, C., and Schroeder, R. (2020). Populist Attitudes and
# Selective Exposure to Online News: A Cross-Country Analysis Combining
# Web Tracking and Surveys.The International Journal of Press/Politics, 25
# (3), 426–46.
# Stier, S., Posch, L., Bleier, A., and Strohmaier, M. (2017). When Populists
# become Popular: Comparing Facebook Use by the Right-Wing Movement
# Pegida and German Political Parties.Information, Communication & Society,
# 20(9), 1365–88.
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.29:
# news media outlets increasingly rely on digital platforms, such as Facebook or
# Twitter, to connect them with audiences (Nielsen & Ganter 2018). This makes
# these companies into powerful new gatekeepers whose internal governance
# remains opaque, including the workings of their algorithms and how they
# shape users’ information environments. At the same time, this has led to
# a weakening of power over the mechanics of informational reach for traditional
# news providers that, in the past, controlled the function of news provision and of
# distribution. Finally, digital media have undermined theﬁnancial basis for
# commercial news production and distribution by transforming the ad business
# and shifting major revenue streams from news organizations to digital infra-
# structures such as Google (Nielsen 2012). These trends have meant traditional
# gatekeepers can be bypassed and have given rise to much soul-searching about
# their current function and business models.
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.1:
# Rethinking the Public Sphere:
# A Contribution to the Critique of Actually Existing
# Democracy'
# NANCY FRASER
# Introduction
# Today in the U.S. we hear a great deal of ballyhoo about "the triumph of
# liberal democracy" and even "the end of history." Yet there is still a great
# deal to object to in our own "actually existing democracy," and the project
# of a critical social theory of the limits of democracy in late capitalist
# societies remains as relevant as ever. In fact, this project seems to me to
# have acquired a new urgency at a time when "liberal democracy" is being
# touted as the ne plus ultra of social systems for countries that are emerg-
# ing from Soviet-style state socialism, Latin American military dictator-
# ships, and southern African regimes of racial domination.
# Those of us who remain committed to theorizing the limits of democ-
# racy in late capitalist societies will find in the work of Jiirgen Habermas
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.78:
# Sehl, A., Simon, F. M., and Schroeder, R. (2020). The Populist Campaigns
# against European Public Service Media: Hot Air or Existential Threat?
# International Communication Gazette.
# Settle, J. E. (2018). Frenemies: How Social Media Polarizes America .
# Cambridge: Cambridge University Press.
# Shoemaker, P. J., and Reese, S. D. (2014).Mediating the Message in the 21st
# Century, 3rd ed. New York: Routledge.
# Shoemaker, P. J., and V os, T. P. (2009).Gatekeeping Theory. New York:
# Routledge.
# Sides, J., Tesler, M., and Vavreck, L. (2018). Identity Crisis: The 2016
# Presidential Campaign and the Battle for the Meaning of America .
# Princeton, NJ: Princeton University Press.
# Skocpol, T., and Tervo, C. (Eds.). (2020). Upending American Politics:
# Polarizing Parties, Ideological Elites, and Citizen Activists from the Tea
# Party to the Anti-Trump Resistance. New York: Oxford University Press.
# Slater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and
#
#
# Answer: I can provide a helpful answer based on the retrieved context.
#
# The concept of the public sphere is not explicitly defined in the provided passages, but it can be inferred from the works of Nancy Fraser (1990) and Jürgen Habermas (1984).
#
# According to Fraser's work, "Rethinking the Public Sphere," the public sphere refers to a critical social theory that examines the limits of democracy in late capitalist societies. The concept is also mentioned by Habermas, who discusses the idea of a communicative public sphere as a space for rational discourse and deliberation.
#
# In general, the public sphere can be understood as a space where citizens engage in public debate, discussion, and deliberation on matters of common interest, such as politics, social issues, and cultural values. It is often associated with the idea of a democratic public sphere, which is characterized by the free flow of information, ideas, and opinions.
#
# However, the provided passages also suggest that the traditional notion of the public sphere is being challenged by digital media and the rise of online platforms, which have created new gatekeepers and altered the dynamics of public discourse.

# %%
print(f'Prompt passed to the model after retreival and summarisation:\n{result["prompt"]} \n\nLength of the prompt: {len(str(result["prompt"]))}')
# Out:
# Prompt passed to the model after retreival and summarisation:
# text='You are a helpful assistant for finding relevant text passages in scientific literature. \nUse the following pieces of retrieved context to answer the question. Each piece of content starts with the indicators "Source" and "Page". Always provide these in your answer when using one of the retrieved passages.\nIf you don\'t know the answer, just say that you don\'t know, don\'t try to make up an answer.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:14\nDahlberg L (2001a) Democracy via cyberspace: Examining the rhetorics and practices of three \nprominent camps. New Media & Society 3(2): 187–207. \nDahlberg L (2001b) The internet and democratic discourse: Exploring the prospects of online \ndeliberative forums extending the public sphere. Information, Communication & Society 4(4): \n615–633.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:15\nGraham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere. \nDoctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.\nHabermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1, \nReason and the Rationalization of Society). Boston, MA: Beacon Press.\n\nSource: test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf\nPage:78\nParty to the Anti-Trump Resistance. New York: Oxford University Press.\nSlater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and\nDemocratization in Developmental Asia. Perspectives on Politics, 11(3),\n717–33.\nSmith, R. M., and King, D. (2020). White Protectionism in America.\nPerspectives on Politics, 19(2), 460–78.\nSobieraj, S. (2020).Credible Threat: Attacks against Women Online and the\nFuture of Democracy. Oxford: Oxford University Press.\nStier, S., Kirkizh, N., Froio, C., and Schroeder, R. (2020). Populist Attitudes and\nSelective Exposure to Online News: A Cross-Country Analysis Combining\nWeb Tracking and Surveys.The International Journal of Press/Politics, 25\n(3), 426–46.\nStier, S., Posch, L., Bleier, A., and Strohmaier, M. (2017). When Populists\nbecome Popular: Comparing Facebook Use by the Right-Wing Movement\nPegida and German Political Parties.Information, Communication & Society,\n20(9), 1365–88.\n\nSource: test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf\nPage:29\nnews media outlets increasingly rely on digital platforms, such as Facebook or\nTwitter, to connect them with audiences (Nielsen & Ganter 2018). This makes\nthese companies into powerful new gatekeepers whose internal governance\nremains opaque, including the workings of their algorithms and how they\nshape users’ information environments. At the same time, this has led to\na weakening of power over the mechanics of informational reach for traditional\nnews providers that, in the past, controlled the function of news provision and of\ndistribution. Finally, digital media have undermined theﬁnancial basis for\ncommercial news production and distribution by transforming the ad business\nand shifting major revenue streams from news organizations to digital infra-\nstructures such as Google (Nielsen 2012). These trends have meant traditional\ngatekeepers can be bypassed and have given rise to much soul-searching about\ntheir current function and business models.\n\nSource: test_data\\Fraser 1990 Rethinking the Public Sphere.pdf\nPage:1\nRethinking the Public Sphere: \nA Contribution to the Critique of Actually Existing \nDemocracy\' \nNANCY FRASER \nIntroduction \nToday in the U.S. we hear a great deal of ballyhoo about "the triumph of \nliberal democracy" and even "the end of history." Yet there is still a great \ndeal to object to in our own "actually existing democracy," and the project \nof a critical social theory of the limits of democracy in late capitalist \nsocieties remains as relevant as ever. In fact, this project seems to me to  ...
#
# Length of the prompt: 5594

# %% [markdown]
# ### With structured Output

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict, Annotated


class AnswerWithSources(TypedDict):
    """An answer to the question, with sources."""

    answer: str
    sources: Annotated[
        List[str],
        ...,
        "List of sources used to answer the question",
    ]


class State(TypedDict):
    question: str
    context: List[Document]
    answer: AnswerWithSources
    prompt: str


def retrieve(state: State):
    retrieved_docs = retriever.invoke(state["question"])
    return {"context": retrieved_docs}
    

def generate(state: State):
    docs_content = "\n\n".join(f'Source: {doc.metadata["source"]}\nPage:{doc.metadata["page"]}\n{doc.page_content}' for doc in state["context"])
    messages = rag_prompt.invoke({"question": state["question"], "context": docs_content})
    structured_llm = llm.with_structured_output(AnswerWithSources)
    response = structured_llm.invoke(messages)
    return {"answer": response,
            "prompt": messages} # return the prompt for debugging purposes

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
q = "What is the definition of the public sphere?"

result = graph.invoke({"question": q})

for doc in result["context"]:
    print(f'{doc.metadata["source"]} p.{doc.metadata["page"]}:\n{doc.page_content} \n\n')

print(f'Answer: {result["answer"]}')
# Out:
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.14:
# Dahlberg L (2001a) Democracy via cyberspace: Examining the rhetorics and practices of three
# prominent camps. New Media & Society 3(2): 187–207.
# Dahlberg L (2001b) The internet and democratic discourse: Exploring the prospects of online
# deliberative forums extending the public sphere. Information, Communication & Society 4(4):
# 615–633.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.15:
# Graham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere.
# Doctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.
# Habermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1,
# Reason and the Rationalization of Society). Boston, MA: Beacon Press.
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.78:
# Party to the Anti-Trump Resistance. New York: Oxford University Press.
# Slater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and
# Democratization in Developmental Asia. Perspectives on Politics, 11(3),
# 717–33.
# Smith, R. M., and King, D. (2020). White Protectionism in America.
# Perspectives on Politics, 19(2), 460–78.
# Sobieraj, S. (2020).Credible Threat: Attacks against Women Online and the
# Future of Democracy. Oxford: Oxford University Press.
# Stier, S., Kirkizh, N., Froio, C., and Schroeder, R. (2020). Populist Attitudes and
# Selective Exposure to Online News: A Cross-Country Analysis Combining
# Web Tracking and Surveys.The International Journal of Press/Politics, 25
# (3), 426–46.
# Stier, S., Posch, L., Bleier, A., and Strohmaier, M. (2017). When Populists
# become Popular: Comparing Facebook Use by the Right-Wing Movement
# Pegida and German Political Parties.Information, Communication & Society,
# 20(9), 1365–88.
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.29:
# news media outlets increasingly rely on digital platforms, such as Facebook or
# Twitter, to connect them with audiences (Nielsen & Ganter 2018). This makes
# these companies into powerful new gatekeepers whose internal governance
# remains opaque, including the workings of their algorithms and how they
# shape users’ information environments. At the same time, this has led to
# a weakening of power over the mechanics of informational reach for traditional
# news providers that, in the past, controlled the function of news provision and of
# distribution. Finally, digital media have undermined theﬁnancial basis for
# commercial news production and distribution by transforming the ad business
# and shifting major revenue streams from news organizations to digital infra-
# structures such as Google (Nielsen 2012). These trends have meant traditional
# gatekeepers can be bypassed and have given rise to much soul-searching about
# their current function and business models.
#
#
# test_data\Fraser 1990 Rethinking the Public Sphere.pdf p.1:
# Rethinking the Public Sphere:
# A Contribution to the Critique of Actually Existing
# Democracy'
# NANCY FRASER
# Introduction
# Today in the U.S. we hear a great deal of ballyhoo about "the triumph of
# liberal democracy" and even "the end of history." Yet there is still a great
# deal to object to in our own "actually existing democracy," and the project
# of a critical social theory of the limits of democracy in late capitalist
# societies remains as relevant as ever. In fact, this project seems to me to
# have acquired a new urgency at a time when "liberal democracy" is being
# touted as the ne plus ultra of social systems for countries that are emerg-
# ing from Soviet-style state socialism, Latin American military dictator-
# ships, and southern African regimes of racial domination.
# Those of us who remain committed to theorizing the limits of democ-
# racy in late capitalist societies will find in the work of Jiirgen Habermas
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.78:
# Sehl, A., Simon, F. M., and Schroeder, R. (2020). The Populist Campaigns
# against European Public Service Media: Hot Air or Existential Threat?
# International Communication Gazette.
# Settle, J. E. (2018). Frenemies: How Social Media Polarizes America .
# Cambridge: Cambridge University Press.
# Shoemaker, P. J., and Reese, S. D. (2014).Mediating the Message in the 21st
# Century, 3rd ed. New York: Routledge.
# Shoemaker, P. J., and V os, T. P. (2009).Gatekeeping Theory. New York:
# Routledge.
# Sides, J., Tesler, M., and Vavreck, L. (2018). Identity Crisis: The 2016
# Presidential Campaign and the Battle for the Meaning of America .
# Princeton, NJ: Princeton University Press.
# Skocpol, T., and Tervo, C. (Eds.). (2020). Upending American Politics:
# Polarizing Parties, Ideological Elites, and Citizen Activists from the Tea
# Party to the Anti-Trump Resistance. New York: Oxford University Press.
# Slater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and
#
#
# Answer: None

# %%
print(f'Prompt passed to the model after retreival and summarisation:\n{result["prompt"]} \n\nLength of the prompt: {len(str(result["prompt"]))}')
# Out:
# Prompt passed to the model after retreival and summarisation:
# text='You are a helpful assistant for finding relevant text passages in scientific literature. \nUse the following pieces of retrieved context to answer the question. Each piece of content starts with the indicators "Source" and "Page". Always provide these in your answer when using one of the retrieved passages.\nIf you don\'t know the answer, just say that you don\'t know, don\'t try to make up an answer.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:14\nDahlberg L (2001a) Democracy via cyberspace: Examining the rhetorics and practices of three \nprominent camps. New Media & Society 3(2): 187–207. \nDahlberg L (2001b) The internet and democratic discourse: Exploring the prospects of online \ndeliberative forums extending the public sphere. Information, Communication & Society 4(4): \n615–633.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:15\nGraham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere. \nDoctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.\nHabermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1, \nReason and the Rationalization of Society). Boston, MA: Beacon Press.\n\nSource: test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf\nPage:78\nParty to the Anti-Trump Resistance. New York: Oxford University Press.\nSlater, D., and Wong, J. (2013). The Strength to Concede: Ruling Parties and\nDemocratization in Developmental Asia. Perspectives on Politics, 11(3),\n717–33.\nSmith, R. M., and King, D. (2020). White Protectionism in America.\nPerspectives on Politics, 19(2), 460–78.\nSobieraj, S. (2020).Credible Threat: Attacks against Women Online and the\nFuture of Democracy. Oxford: Oxford University Press.\nStier, S., Kirkizh, N., Froio, C., and Schroeder, R. (2020). Populist Attitudes and\nSelective Exposure to Online News: A Cross-Country Analysis Combining\nWeb Tracking and Surveys.The International Journal of Press/Politics, 25\n(3), 426–46.\nStier, S., Posch, L., Bleier, A., and Strohmaier, M. (2017). When Populists\nbecome Popular: Comparing Facebook Use by the Right-Wing Movement\nPegida and German Political Parties.Information, Communication & Society,\n20(9), 1365–88.\n\nSource: test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf\nPage:29\nnews media outlets increasingly rely on digital platforms, such as Facebook or\nTwitter, to connect them with audiences (Nielsen & Ganter 2018). This makes\nthese companies into powerful new gatekeepers whose internal governance\nremains opaque, including the workings of their algorithms and how they\nshape users’ information environments. At the same time, this has led to\na weakening of power over the mechanics of informational reach for traditional\nnews providers that, in the past, controlled the function of news provision and of\ndistribution. Finally, digital media have undermined theﬁnancial basis for\ncommercial news production and distribution by transforming the ad business\nand shifting major revenue streams from news organizations to digital infra-\nstructures such as Google (Nielsen 2012). These trends have meant traditional\ngatekeepers can be bypassed and have given rise to much soul-searching about\ntheir current function and business models.\n\nSource: test_data\\Fraser 1990 Rethinking the Public Sphere.pdf\nPage:1\nRethinking the Public Sphere: \nA Contribution to the Critique of Actually Existing \nDemocracy\' \nNANCY FRASER \nIntroduction \nToday in the U.S. we hear a great deal of ballyhoo about "the triumph of \nliberal democracy" and even "the end of history." Yet there is still a great \ndeal to object to in our own "actually existing democracy," and the project \nof a critical social theory of the limits of democracy in late capitalist \nsocieties remains as relevant as ever. In fact, this project seems to me to  ...
#
# Length of the prompt: 5594

# %%
import json

print(json.dumps(result["answer"], indent=2)) # the sources provided here are not in the provided context - that is, they are made up and not part of the RAG pipeline!
# Out:
# null

# %% [markdown]
# The structured output prompting tool seems to lead to considerable hallucinations in the model. Rather than naming the provided sources, as in the non-structured output, the model makes up new sources not provided in the context window. In other words, the sources referred to by the model are NOT part of the RAG pipeline!
# Additionally note that, when provided with chunks rather than full pages, the model fails completey, not giving any answer (none/null).

# %% [markdown]
# ## RAG with Summarisation Step

# %%
# check if the folder db_directory already exists. If not, creat it and load the documents into the vector store. Else, use the existing vector store. Makes a new DB for shortened docs

db_directory = "./test_chroma_db" # directory to save the vector store

short_docs = False # for the summarisation pipeline, we can use unshortened docs

retriever_type = "mmr" # "similarity"  or "mmr"

if short_docs:
    db_directory += "_short"

if not os.path.exists(db_directory):
    # load documents
    loader = PyPDFDirectoryLoader(
    "./test_data/")
    docs = loader.load() # metadata tracks paper and page number; each page is a single document

    # optional step: split the docs into smaller chunks to fit into context window of the model (model dependant, necessary for small models) -!! test this, shorter chunks may lead to bad retrieval results !!-
    #           potential remedy: use whole pages, but use the model to summarise each page before chaining it into the context
    if short_docs:
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,  # chunk size (characters)
            chunk_overlap=200,  # chunk overlap (characters)
            add_start_index=True,  # track index in original document
            )
        docs = text_splitter.split_documents(docs)

    # make doc vector store. as the vector store can get quite large (and takes time to initialize in memory), we use a chroma database to store the vectors    
    vector_store = Chroma(
        collection_name="lit_helper_test",
        embedding_function=embeddings,
        persist_directory=db_directory,  # save data locally
        )
    vector_store.add_documents(docs) # add docs

else:
    vector_store = Chroma(
        collection_name="lit_helper_test",
        embedding_function=embeddings,
        persist_directory=db_directory,  # save data locally
    )


docs_returned = 6 # number of docs returned by the retriever(s)

# turn the vector store into retriever(s)

if retriever_type == "mmr":
    retriever = vector_store.as_retriever(
        search_type="mmr", # MMR (Maximal Marginal Relevance) aims to diversify search results. the amount of diversification is set via the lambda_mult parameter
        search_kwargs={"k": docs_returned, "fetch_k": 30, "lambda_mult": 0.8}, # make sure the number of documents passed (k) fits into the context window
    )

if retriever_type == "similarity":
    retriever = vector_store.as_retriever(
        search_type="similarity", # similarity score; optionally with threshold ("similarity_score_threshold" with "score_threshold" kwarg)
        search_kwargs={"k": docs_returned}, # make sure the number of documents passed (k) fits into the context window
    )

# %%
template = """You are a helpful assistant for finding relevant text passages in scientific literature. 
You can use the following summaries of retrieved text passages to answer the question. Each summary starts with the indicators "Source" and "Page". Always provide these in your answer if using one of the retrieved passages. 
Only use summaries that are relevant to the question at hand.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}

Helpful answer:"""

rag_prompt = PromptTemplate.from_template(template)


summarise_template = """Summarise the following text passage with regard to this question: {question}

{text}

Summary:"""

summarise_prompt = PromptTemplate.from_template(summarise_template)

# %%
from langchain_core.documents import Document
from typing_extensions import List, TypedDict


class State(TypedDict):
    question: str
    text: str
    summaries: List[Document]
    context: List[Document]
    answer: str
    prompt: str


def retrieve(state: State):
    retrieved_docs = retriever.invoke(state["question"])
    return {"context": retrieved_docs}
    

def summarise(state: State):
    summaries = []
    for doc in state["context"]:
        text = doc.page_content
        messages = summarise_prompt.invoke({"question": state["question"], "text": text})
        summary = Document( # store the summary as a Document type object for consistency
            page_content = llm.invoke(messages).content,
            metadata = {"source": doc.metadata["source"], "page": doc.metadata["page"]})
        summaries.append(summary)
    return {"summaries": summaries}


def generate(state: State):
    summaries = "\n\n".join(f'Source: {doc.metadata["source"]}\nPage:{doc.metadata["page"]}\n{doc.page_content}' for doc in state["summaries"])
    messages = rag_prompt.invoke({"question": state["question"], "context": summaries})
    response = llm.invoke(messages)
    return {"answer": response.content, 
            "prompt": messages} # return the prompt for debugging purposes

# %%
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([retrieve, summarise, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
q = "What is the definition of the public sphere?"

result = graph.invoke({"question": q}) # due to the summarisation step, this will take longer than the previous pipeline

for i in range(len(result["context"])):
    print(f'{result["context"][i].metadata["source"]} p.{result["context"][i].metadata["page"]}.\nText:\n{result["context"][i].page_content}\nSummary:\n{result["summaries"][i].page_content}\n\n')

print(f'Answer: {result["answer"]}')
# Out:
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.2.
# Text:
# Dahlberg 857
# third element refers to the specific ways in which digital media is seen to be supporting
# the development of the other two elements. I have chosen the term affordances as it
# broadly captures how all the positions tend to understand the human–technology
# relationship. In general terms, the relationship is one where the technology is seen to
# have certain features that enable (afford) particular democratic uses and outcomes. 1
# Finally, I explored how digital democracy commentary and practice was positioned in
# relation to these three immanent, interrelated, and mutually effecting elements. This
# enabled me to reconstruct  a number of positions, including the four outlined in this
# article.2 As interpretatively reconstructed representations of the articulations of empirical
# instances, the resulting positions are open to (and indeed invite) challenge and rewriting
# in digital democracy scholarship.
# The empirical material from which I reconstructed the four positions consists of a
# combination of e-democracy commentary, academic research, and digital democracy
# practice. I do not specifically differentiate between ‘theoretical’ and ‘practical’ materials. I
# see these as mutually implicated. Practices embody systems of ideas, and such systems are
# not only themselves a form of practice but draw from practical experience. Moreover, given
# the heterogeneous and ever-changing nature of this material – the ‘set’ of all to do with
# digital democracy – ‘representative’ sampling was rejected. Rather, in accord with a critical-
# interpretative approach, I drew upon my knowledge and previous research in the field to
# choose what I considered exemplary digital democracy texts and practices. My choice of
# exemplars, as well as my subsequent reading, is necessarily marked by my subjective
# experience and judgement, and given ongoing developments in the field invites rereading.
# I name the four reconstructed positions liberal-individualist, deliberative, counter-
# publics, and autonomist Marxist. My research indicates that these positions characterize
# widely influential understandings in digital democracy rhetoric and practice. However, I do
# not claim that they in any way exhaust the e-democracy positions that could be explicated.
# Given more space and research resources we could identify and explore a number of other
# e-democracy articulations, including cyber-feminist (for example, Fernandez et al., 2004;
# Fuller, 2004; Hall, 1996; Plant, 1996), communitarian (see Dahlberg, 2001a), cyber-liber-
# tarian (see Dahlberg, 2010), liberal digital commonism (for example, Benkler, 2006; Lessig,
# 2001), and postmodern (for example, Nguyen and Alexander, 1996; Poster, 2001). It would
# also be interesting to ask if distinct positions could be seen developing out of experiences
# of subalternity, particularly in relation to the Global South. In addition, we could outline
# more cautious, and even dystopian, positions (see Kroker and Kroker, 1997; Kroker and
# Weinstein, 1994). Moreover, e-democracy would be characterized differently if we were to
# identify, and deploy as organizing dimensions, elements immanent to rhetoric and practice
# other than the three used here (such as those listed above). However, I found the three
# elements deployed to be central in digital democracy articulations. While necessarily
# limited in scope, I believe that the resulting outline brings much needed attention to digital
# democracy’s diversity and provides a framework for further research.
# Liberal-individualist digital democracy
# Much digital democracy discussion and practice draws upon what I refer to as a liberal-
# individualist understanding of democracy. I refer to this position as liberal-individualist
# Summary:
# The text passage does not explicitly define the public sphere, but it discusses the concept of "digital democracy" and its relationship with various theoretical positions.
#
# However, based on the context, it can be inferred that the author is discussing the concept of digital democracy in relation to the public sphere. The public sphere refers to a space where citizens engage in public discourse, debate, and participation in democratic processes.
#
# The passage suggests that digital media has enabled new forms of democratic engagement, but also notes that different theoretical positions have emerged to understand this relationship. These positions include liberal-individualist, deliberative, counter-publics, and autonomist Marxist, among others.
#
# While the passage does not explicitly define the public sphere, it implies that the concept is relevant to understanding digital democracy and its various articulations.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.10.
# Text:
# Dahlberg 865
# Table 2. Affordances in the four digital democracy positions
# Digital Democratic Affordances
# Liberal-consumer aggregating, calculating, choosing, competing, expressing,
# fundraising, informing, petitioning, registering, transacting,
# transmitting, voting
# Deliberative agreeing, arguing, deliberating, disagreeing, informing, meeting,
# opinion forming, publicizing, reflecting
# Counter-publics articulating, associating, campaigning, contesting, forming groups,
# identifying, organizing, protesting, resisting
# Autonomous Marxist collaborating, cooperating, distributing, exchanging, giving,
# networking, participating, sharing
# Table 1. Subject and democracy in the four digital democracy positions
# Subject Democracy
# Liberal-consumer self-sufficient, rational-strategic individual competitive-aggregative
# Deliberative inter-subjectively rational individual deliberative-consensual
# Counter-publics discursive-antagonistic individual/public contestationary
# Autonomous Marxist multitude of singularities commons networking
# in alphabetical order, as a summary of the democratic affordances that each position
# identifies with digital media technology. These signifiers should not be taken as a hard or
# final defining of these positions, which are dynamic. Neither should the signifiers be
# seen as unique to each position. Rather, the list of signifiers in Table 2 represents a rough
# indication of each of the positions with respect to how they understand the democratic
# affordances of digital technology.
# With respect to these affordances, I have not attempted to differentiate between how
# positions understand the relationship between human agency and technological effects.
# An investigation of such a differentiation is complex and beyond the scope of this article.
# I will simply note that the rhetoric and practice from out of which the four positions were
# reconstructed assume an understanding somewhere along the spectrum between ‘uses’
# and ‘constitution’ models of human–technology relations (see Dahlberg, 2004; Poster,
# 2001). Sometimes the technology is understood more as a ‘tool’ for uses determined by
# independent human agents, as in communication conduits or the means for engaging in
# activism. At other times digital media are seen more constitutively, as bringing into being
# particular spaces, objects, subjects, and practices. One general observation, however, can
# be made. This is that the rhetoric and practice of the liberal-individualist position tends
# to read digital media as most tool-like (able to be developed and deployed at will by
# individuals and groups to meet their needs and desires), while the autonomist position
# takes the most constitutive understanding, seeing digital communication networks as
# bringing into existence a new democratic society. However, within all four positions we
# Summary:
# The text passage does not explicitly define the public sphere. It appears to be discussing different digital democracy positions and their understandings of democratic affordances in relation to digital media technology. The author notes that they did not attempt to differentiate between how these positions understand the relationship between human agency and technological effects, but rather provides a rough indication of each position's understanding of democratic affordances.
#
# However, based on the context, it can be inferred that the public sphere is likely being discussed in relation to the concept of digital democracy and its various interpretations. The author mentions "publicizing" and "publicizing" as one of the affordances listed under the Deliberative position, which suggests a connection to the idea of a public sphere.
#
# In general, the public sphere refers to a space where citizens can engage in public discourse, debate, and discussion about issues that affect them. It is often seen as a key component of democratic societies, allowing for the exchange of ideas and the formation of public opinion. The concept of the public sphere has been discussed extensively in the context of digital media and democracy, with many scholars arguing that new technologies have created new opportunities for public engagement and participation.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.16.
# Text:
# Dahlberg 871
# Habermas J (1989) The Structural Transformation of the Public Sphere: An Inquiry into a Category
# of Bourgeois Society (trans. Thomas Burger). Cambridge, MA: MIT Press.
# Habermas J (1996) Between Facts and Norms: Contributions to a Discourse Theory of Law and
# Democracy (trans. William Rehg). Cambridge, UK: Polity Press.
# Habermas J (2006) Political communication in media society: Does democracy still enjoy an
# epistemic dimension? The impact of normative theory on empirical research. Communication
# Theory 16(4): 411–426.
# Hall K (1996) Cyberfeminism. In: Herring SC (ed.) Computer-mediated Communication:
# Linguistic, Social and Cross-cultural Perspectives. Amsterdam: John Benjamins, 147–170.
# Hardt M and Negri A (2004) Multitude: War and Democracy in the Age of Empire . New York:
# Penguin.
# Hardt M and Negri A (2009) Commonwealth. Cambridge, MA: Harvard University Press.
# Hindman M (2009) The Myth of Digital Democracy. Princeton, NJ: Princeton University Press
# Janssen D and Kies R (2005) Online forums and deliberative democracy. Acta Politica 40(3):
# 384–392.
# Johnston J and Laxer G (2003) Solidarity in the age of globalization: Lessons from the anti-MAI
# and Zapitista struggles. Theory and Society 32(1): 39–91.
# Jordan T (2007) Online direct action: Hactivism and radical democracy. In: Dahlberg L and Siapera
# E (eds) Radical Democracy and the Internet. New York: Palgrave, 73–88.
# Kahn R and Kellner D (2005) Oppositional politics and the internet: A critical/reconstructive
# approach Cultural Politics: An International Journal 1(1): 75–100.
# Kahn R and Kellner D (2007) Globalization, technopolitics and radical democracy. In: Dahlberg L
# and Siapera E (eds) The Internet and Radical Democracy: Interrogating Theory and Practice.
# London: Palgrave, 17–36.
# Kidd D (2003) Indymedia.org: A new communications commons. In: McCaughey M and Ayers
# MD (eds) Cyberactivism: Online Activism in Theory and Practice.  New York: Routledge,
# 47–70.
# Kowal D M (2002) Digitizing and globalizing indigenous voices: The Zapatista movement. In:
# Elmer G (ed.) Critical Perspectives on the Internet . Lanham, MA: Rowman and Littlefield,
# 105–126.
# Kroker A and Kroker M (eds) (1997) Digital Delirium. New York: New World Perspectives.
# Kroker A and Weinstein MA (1994) Data Trash: The Theory of the Virtual Class . New York: St
# Martin’s Press.
# Langman L (2005) From virtual public spheres to global justice: A critical theory of internet -
# worked social movements. Sociological Theory 23(1): 42–74.
# Lessig L (2001) The Future of Ideas: The Fate of the Commons in a Connected World. New York:
# Random House.
# London S (1995) Teledemocracy vs deliberative democracy: A comparative look at two models of
# public talk. Journal of Interpersonal Computing and Technology 3(2): 33–35.
# McDorman T F (2001) Crafting a virtual counterpublic: Right-to-die advocates on the internet.
# In: Asen R and Brouwer DC (eds) Counterpublics and the State . Albany, NY: SUNY Press,
# 187–210.
# Mitra A (2004) V oices of the marginalized on the internet: Examples from a website for women of
# South Asia. International Journal of Communication 54(3): 492–510.
# Mouffe C (2005) For an agonistic public sphere. In: Tønder L and Thomassen L (eds) Radical
# Democracy: Politics Between Abundance and Lack . Manchester: University of Manchester
# Press, 123–132.
# Negri A (2008a) The Porcelain Workshop: For a New Grammar of Politics. New York: Semiotext(e).
# Negri A (2008b) Empire and Beyond. Cambridge, UK: Polity.
# Summary:
# Unfortunately, the provided text passage does not contain any information about the definition of the public sphere. The texts appear to be a collection of academic articles and book excerpts related to digital media, democracy, and radical politics, but none of them discuss the concept of the public sphere or provide a definition.
#
# However, based on general knowledge, I can provide a brief summary of the concept of the public sphere:
#
# The public sphere is a theoretical concept that refers to a space where citizens engage in public discourse, debate, and discussion about issues affecting society. It is often associated with the idea of a democratic public, where individuals can freely express their opinions, participate in deliberation, and hold those in power accountable.
#
# In the context of digital media, the public sphere has been redefined to include online spaces such as social media platforms, blogs, and forums, which have become important sites for public engagement and debate.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.15.
# Text:
# 870 new media & society 13(6)
# Dahlberg L (2004) Internet research tracings: Towards non-reductionist methodology. Journal of
# Computer-mediated Communications 9(3). Available at: http://jcmc.indiana.edu/vol9/issue3/
# dahlberg.html (consulted September 2010).
# Dahlberg L (2007a) The Internet and discursive exclusion.  In: Dahlberg L and Siapera E (eds)
# Radical Democracy and the Internet: Exploring Theory and Practice.  London: Palgrave,
# 128–147.
# Dahlberg L (2007b) Rethinking the fragmentation of the cyber-public: From consensus to contes-
# tation. New Media & Society 9(5): 829–849.
# Dahlberg L (2010) Cyber-libertarianism 2.0: A Discourse theory/critical political economy exami-
# nation. Cultural Politics 6(3): 331–356.
# Dahlgren P (2007) Civic identity and net activism: The frame of radical democracy. In: Dahlberg L
# and Siapera E (eds) Radical Democracy and the Internet: Interrogating Theory and Practice.
# New York: Palgrave, 55–72.
# Dietz M (1992) Context is all, feminism and theories of citizenship. In: Mouffe C (ed.) Dimensions
# of Radical Democracy. London: Verso, 63–85.
# Downey J and Fenton N (2003) New media, counter publicity and the public sphere.  New Media
# & Society 5(2): 185–202.
# Dyer-Witheford N (2002) The new combinations. The New Centennial Review 1(3): 155–200.
# Dyer-Witheford N (2006) Species-being and the new commonism: Notes on an interrupted cycle
# of struggles. The Commoner 11(Spring): 15–32.
# Dyer-Witheford N (2007) Hegemony or multitude? Two versions of radical democracy for the net.
# In: Dahlberg L and Siapera E (eds), Radical Democracy and the Internet. New York: Palgrave,
# 191–206.
# Fang N-H (1995) The Internet as a public sphere: A Habermasian approach. Unpublished doctoral
# dissertation, State University of New York, Buffalo.
# Fernandez M, Wilding F and Wright M (eds) (2004) Domain Errors! Cyberfeminist Practices .
# London: Pluto Press.
# Fraser N (1992) Rethinking the public sphere: A contribution to the critique of actually existing
# democracy. In: Barker F, Hulme P and Iversen M (eds) Postmodernism and the Re-reading of
# Modernity. Manchester: Manchester University Press, 197–231.
# Friedland LA, Hove T and Rojas H (2006) The networked public sphere. Javnost – the Public
# 13(4): 5–26.
# Fuller M (2004) Behind the Blip: Essays on the Culture of Software. London: Pluto Press.
# Gallo J (2003) Online Oppositional Communities as Discursive Counterpublics. Paper presented
# at the Association of Internet Researchers Conference, Toronto, October.
# Gibson JJ (1977) The theory of affordances. In: Shaw R and Bransford J (eds) Perceiving, Acting,
# and Knowing: Toward an Ecological Psychology. Hillsdale, NJ: Lawrence Erlbaum, 67–82.
# Gillet J (2007) Internet web logs as cultural resistance: A case study of the SARS Arts Project.
# Journal of Communication Inquiry 31(1): 28–43.
# Gimmler A (2001) Deliberative democracy, the public sphere and the internet. Philosophy and
# Social Criticism 27(4): 21–39.
# Glynos J and Howarth D (2007) Logics of Critical Explanation in Social and Political Theory .
# London: Routledge.
# Gore A (1994) The global information infrastructure: Forging a new Athenian age of democracy.
# Intermedia 22(2): 4–7.
# Graham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere.
# Doctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.
# Habermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1,
# Reason and the Rationalization of Society). Boston, MA: Beacon Press.
# Summary:
# The provided text passage does not explicitly define the public sphere. However, it appears to be a collection of academic articles and book chapters related to the concept of the public sphere, particularly in the context of new media and internet studies.
#
# The texts referenced in the passage are primarily from scholars who have contributed to the ongoing debate about the nature and evolution of the public sphere in the digital age. Some authors, such as Habermas (1984), Fraser (1992), and Dahlberg (2007a), discuss the concept of the public sphere in relation to traditional notions of civic discourse and democratic participation.
#
# However, there is no single definition or clear consensus on what constitutes the public sphere in the context of new media. The texts suggest that the public sphere has undergone significant transformations with the advent of digital technologies, and scholars are grappling with questions such as:
#
# * What forms does the public sphere take in online spaces?
# * How do digital technologies shape our understanding of civic discourse and democratic participation?
# * Can the internet be seen as a new public sphere, or is it something distinct from traditional notions of the public sphere?
#
# Overall, while the passage provides insight into the ongoing debates surrounding the concept of the public sphere, it does not offer a definitive definition.
#
#
# test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf p.3.
# Text:
# 858 new media & society 13(6)
# because it focuses on the opportunities afforded to individuals to have their particular
# interests realized through liberal political systems. I will briefly outline the democratic
# affordances offered by digital media that this position highlights, before identifying the
# assumed democratic subject and associated understanding of democracy.
# Liberal-individualist digital democracy understands digital media as offering a
# means for the effective transmission of information and viewpoints between individuals
# and representative decision-making processes (for example, Gore, 1994, in relation to
# the early internet, and Chadwick, 2009, in relation to digital social networking develop-
# ments). Digital media are understood here as enabling individuals to gain the informa -
# tion they need to examine competing political positions and problems, and as providing
# them with the means for the registration, and subsequent aggregation (as ‘public opin -
# ion’), of their choices (through e-voting, web feedback systems, petitions, e-mail,
# online polls, etc.).
# This liberal-individualist position is being advanced through a range of local and
# national government e-democracy initiatives (see examples in Chadwick, 2009, and at
# Steven Clift’s site at http://www.publicus.net/), as well as through commercial sites (for
# example, australianpolitics.com, speakout.com, vote.com), corporate media-politics
# sites (in particular, corporate news sites providing ‘public opinion’ polling and ‘have
# your say’ comment systems), ‘independent’ e-democracy projects (for example, calvoter.
# org, mysociety.org, theglobalvote.org, votinginfoproject.org, vote-smart.org, 2gov.org),
# and civil society practices (for example, Amnesty International, Avaaz.org, Avaaz’s
# parent Moveon.org, and Avaaz’s founding partner Getup!).  In the case of Amnesty
# International, the internet (text, audio, and video) and other digital media (cell phones
# and video cameras) are deployed as  tools through which liberty-interested individuals
# can take action on exposed ‘rights’ violations around the world, transmitting information
# on human rights abuses and providing the means to undertake individual actions (e-mailing
# government officials, signing e-mail petitions, making electronic donations to appeals,
# participating in online polls, and filing membership applications).
# This Amnesty case demonstrates how the international communication enabled by the
# internet is being harnessed by certain organizations to extend liberal-individualist demo-
# cratic actions globally. Avaaz.org, for instance, looms as the largest campaigning organi-
# zation in history, if one measures size by numbers of individuals virtually participating
# in its campaigns. It uses e-mail and simple internet petitions to enable (and encourage)
# individuals to add their names (if not voices) to those of others with the hope of bringing
# global ‘public opinion’ to bear on decision makers in relation to a wide range of interna-
# tional issues, including global warming, transnational military actions, ‘natural’ disaster
# relief, and global economic management.
# The democratic subject of this liberal-individualist position combines a couple of
# aspects. First, it is understood to be an individual,  rational, self-seeking, instrumental
# utility maximizer who knows his/her own best interests. This self clearly reflects the
# classic liberal economic agent found in Schumpeter (1976: 169), through which
# ‘citizenship becomes less a collective, political activity than an individual, economic
# activity – the right to pursue one’s interests, without hindrance, in the marketplace’
# (Dietz, 1992: 67). However, room is also made for the self as, in a more Rawlsian vein,
# it is capable of empathizing with and supporting the needs and ‘rights’ of other individuals,
# Summary:
# The text passage discusses the concept of the public sphere in relation to liberal-individualist digital democracy. The definition of the public sphere can be summarized as follows:
#
# * It refers to the opportunities afforded to individuals to have their particular interests realized through liberal political systems.
# * Digital media are seen as enabling individuals to effectively transmit information and viewpoints, register their choices, and aggregate public opinion.
# * This concept is advanced through various e-democracy initiatives, commercial sites, corporate media-politics sites, independent e-democracy projects, and civil society practices.
# * The democratic subject of this liberal-individualist position combines two aspects: an individual who knows their own best interests (rational, self-seeking) and a self that can empathize with and support the needs and rights of others.
#
# In essence, the public sphere in this context is seen as a space where individuals can engage with politics and make their voices heard through digital media, enabling them to participate in decision-making processes and shape public opinion.
#
#
# test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf p.57.
# Text:
# those employed in heavily impacted sectors of the economy. The issue is not
# whether economic models indicate the need for austerity policies, but if these
# models account for enough of human life or the boundaries of economic
# protection as to be meaningful.
# The opposition to experts is already a common feature among populist
# challengers and other civil society challengers but it could spread more widely
# if these crises further increase reliance on expertise that constrain political
# options, and media and professional institutions weaken. This opposition ques-
# tions the legitimacy of experts and scientists to limit the will of the people.
# Once peoples’ options in exercising their occupations or personal freedoms
# become narrowed by the say-so of experts and scientists, people will challenge
# their legitimacy. This might not be true for a majority (Bertsou & Caramani
# 2020), especially since the COVID-19 pandemic seems to have led to an
# increase in popular trust in scientists. A heavily mobilized, highly intercon-
# nected critical minority might be enough, however, to mount an effective
# challenge. One early example is the“Querdenker” (contrarian thinkers) move-
# ment in Germany, a vocal and increasingly radicalized minority in Germany
# opposed to the government’s interventions to stop the spread of COVID-19,
# which attacks leading epidemiologists and sees scientists as being in the pocket
# of Big Pharma. When scientiﬁc epistemologies and expert advice increasingly
# set the agenda in a consensus-oriented public arena, their position in difﬁcult
# times is bound to be challenged. This atmosphere threatens to unearth the
# inherent potential conﬂict that emerges between science and democracy when
# an objective approach to understand and explain the world comes to be seen as
# a “religion of an elite” (Lippman 1928: 39)– in this case a technocratic elite–
# and accordingly democratically rejected.
# The structural tensions of public arenas described above force these conﬂicts
# into the open. Just as politicians and journalists before them (Gurri 2018),
# scientists and experts canﬁnd their institutional standing or authority chal-
# lenged (Levin 2020) and must face their challengers in the public arena and
# defend their epistemologies and conclusions. This is vital and justiﬁed if they
# expect for their advice to limit the opportunities, choices, economic prospects,
# and personal freedoms if followed by governments.3 Western democratic insti-
# tutions especially may have to get used to the noise and heat of the contempor-
# ary public arena instead of hoping to somehow turn back the clock to
# a centralized and orderly public arena.
# 3 This means also stepping away from fashionable relativistic posturing. It is notable here that even
# academics in theﬁeld of science and technology studies, whose main stance has been to deny the
# objectivity of science for several decades, now, in the face of climate change and the pandemic,
# 52 Politics and Communication
# https://doi.org/10.1017/9781009064484
#  Published online by Cambridge University Press
# Summary:
# The text passage does not explicitly define the public sphere. However, it discusses the challenges to expertise and scientific authority in the context of a democratic public arena.
#
# The author suggests that as economic models become more influential, they may constrain political options and lead to increased opposition from populist challengers and civil society groups. This opposition questions the legitimacy of experts and scientists, potentially threatening their authority and influence.
#
# The passage implies that the public sphere is a space where science and expertise are subject to scrutiny and challenge, particularly in times of crisis or when scientific advice has significant implications for policy decisions. The author notes that this confrontation between science and democracy can be intense and may require experts to defend their epistemologies and conclusions in the public arena.
#
# Overall, while the passage does not provide a formal definition of the public sphere, it highlights its importance as a space where expertise is subject to democratic scrutiny and challenge.
#
#
# Answer: Based on the summaries provided, I can offer some insights into the concept of the public sphere. However, please note that there is no single, definitive definition of the public sphere across all relevant texts.
#
# From Source: test_data\Dahlberg 2011 Re-Constructing Digital Democracy.pdf:
#
# * The public sphere refers to a space where citizens engage in public discourse, debate, and discussion about issues affecting society.
# * It is often associated with the idea of a democratic public, where individuals can freely express their opinions, participate in deliberation, and hold those in power accountable.
#
# From Source: test_data\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf:
#
# * The public sphere is a space where science and expertise are subject to scrutiny and challenge, particularly in times of crisis or when scientific advice has significant implications for policy decisions.
# * It is a space where democratic values and processes are put into practice, allowing citizens to engage with politics and make their voices heard.
#
# From general knowledge:
#
# * The public sphere is often seen as a key component of democratic societies, allowing for the exchange of ideas and the formation of public opinion.
# * It can take various forms, including traditional civic discourse, online spaces such as social media platforms, blogs, and forums, and other digital environments.
#
# While these summaries provide some insight into the concept of the public sphere, it is essential to note that there is no single definition or clear consensus on what constitutes the public sphere in the context of new media. The texts suggest that the public sphere has undergone significant transformations with the advent of digital technologies, and scholars are grappling with questions such as:
#
# * What forms does the public sphere take in online spaces?
# * How do digital technologies shape our understanding of civic discourse and democratic participation?
#
# I don't know a definitive answer to your question about the definition of the public sphere.

# %%
print(f'Prompt passed to the model after retreival and summarisation:\n{result["prompt"]} \n\nLength of the prompt: {len(str(result["prompt"]))}')
# Out:
# Prompt passed to the model after retreival and summarisation:
# text='You are a helpful assistant for finding relevant text passages in scientific literature. \nYou can use the following summaries of retrieved text passages to answer the question. Each summary starts with the indicators "Source" and "Page". Always provide these in your answer if using one of the retrieved passages. \nOnly use summaries that are relevant to the question at hand.\nIf you don\'t know the answer, just say that you don\'t know, don\'t try to make up an answer.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:2\nThe text passage does not explicitly define the public sphere, but it discusses the concept of "digital democracy" and its relationship with various theoretical positions.\n\nHowever, based on the context, it can be inferred that the author is discussing the concept of digital democracy in relation to the public sphere. The public sphere refers to a space where citizens engage in public discourse, debate, and participation in democratic processes.\n\nThe passage suggests that digital media has enabled new forms of democratic engagement, but also notes that different theoretical positions have emerged to understand this relationship. These positions include liberal-individualist, deliberative, counter-publics, and autonomist Marxist, among others.\n\nWhile the passage does not explicitly define the public sphere, it implies that the concept is relevant to understanding digital democracy and its various articulations.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:10\nThe text passage does not explicitly define the public sphere. It appears to be discussing different digital democracy positions and their understandings of democratic affordances in relation to digital media technology. The author notes that they did not attempt to differentiate between how these positions understand the relationship between human agency and technological effects, but rather provides a rough indication of each position\'s understanding of democratic affordances.\n\nHowever, based on the context, it can be inferred that the public sphere is likely being discussed in relation to the concept of digital democracy and its various interpretations. The author mentions "publicizing" and "publicizing" as one of the affordances listed under the Deliberative position, which suggests a connection to the idea of a public sphere.\n\nIn general, the public sphere refers to a space where citizens can engage in public discourse, debate, and discussion about issues that affect them. It is often seen as a key component of democratic societies, allowing for the exchange of ideas and the formation of public opinion. The concept of the public sphere has been discussed extensively in the context of digital media and democracy, with many scholars arguing that new technologies have created new opportunities for public engagement and participation.\n\nSource: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf\nPage:16\nUnfortunately, the provided text passage does not contain any information about the definition of the public sphere. The texts appear to be a collection of academic articles and book excerpts related to digital media, democracy, and radical politics, but none of them discuss the concept of the public sphere or provide a definition.\n\nHowever, based on general knowledge, I can provide a brief summary of the concept of the public sphere:\n\nThe public sphere is a theoretical concept that refers to a space where citizens engage in public discourse, debate, and discussion about issues affecting society. It is often associated with the idea of a democratic public, where individuals can freely express their opinions, participate in deliberation, and hold those in power accountable.\n\nIn the context of digital media, the public sphere has been redefined to include online spaces such as social media platforms, blogs, and forums, which have become important sites for  ...
#
# Length of the prompt: 8028

# %%
result
# Out:
# {'question': 'What is the definition of the public sphere?',
#  'summaries': [Document(metadata={'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf', 'page': 2}, page_content='The text passage does not explicitly define the public sphere, but it discusses the concept of "digital democracy" and its relationship with various theoretical positions.\n\nHowever, based on the context, it can be inferred that the author is discussing the concept of digital democracy in relation to the public sphere. The public sphere refers to a space where citizens engage in public discourse, debate, and participation in democratic processes.\n\nThe passage suggests that digital media has enabled new forms of democratic engagement, but also notes that different theoretical positions have emerged to understand this relationship. These positions include liberal-individualist, deliberative, counter-publics, and autonomist Marxist, among others.\n\nWhile the passage does not explicitly define the public sphere, it implies that the concept is relevant to understanding digital democracy and its various articulations.'),
#   Document(metadata={'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf', 'page': 10}, page_content='The text passage does not explicitly define the public sphere. It appears to be discussing different digital democracy positions and their understandings of democratic affordances in relation to digital media technology. The author notes that they did not attempt to differentiate between how these positions understand the relationship between human agency and technological effects, but rather provides a rough indication of each position\'s understanding of democratic affordances.\n\nHowever, based on the context, it can be inferred that the public sphere is likely being discussed in relation to the concept of digital democracy and its various interpretations. The author mentions "publicizing" and "publicizing" as one of the affordances listed under the Deliberative position, which suggests a connection to the idea of a public sphere.\n\nIn general, the public sphere refers to a space where citizens can engage in public discourse, debate, and discussion about issues that affect them. It is often seen as a key component of democratic societies, allowing for the exchange of ideas and the formation of public opinion. The concept of the public sphere has been discussed extensively in the context of digital media and democracy, with many scholars arguing that new technologies have created new opportunities for public engagement and participation.'),
#   Document(metadata={'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf', 'page': 16}, page_content='Unfortunately, the provided text passage does not contain any information about the definition of the public sphere. The texts appear to be a collection of academic articles and book excerpts related to digital media, democracy, and radical politics, but none of them discuss the concept of the public sphere or provide a definition.\n\nHowever, based on general knowledge, I can provide a brief summary of the concept of the public sphere:\n\nThe public sphere is a theoretical concept that refers to a space where citizens engage in public discourse, debate, and discussion about issues affecting society. It is often associated with the idea of a democratic public, where individuals can freely express their opinions, participate in deliberation, and hold those in power accountable.\n\nIn the context of digital media, the public sphere has been redefined to include online spaces such as social media platforms, blogs, and forums, which have become important sites for public engagement and debate.'),
#   Document(metadata={'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf', 'page': 15}, page_content='The provided text passage does not explicitly define the public sphere. However, it appears to be a collection of academic articles and book chapters related to the concept of the public sphere, particularly in the context of new media and internet studies.\n\nThe texts referenced in the passage are primarily from scholars who have contributed to the ongoing debate about the nature and evolution of the public sphere in the digital age. Some authors, such as Habermas (1984), Fraser (1992), and Dahlberg (2007a), discuss the concept of the public sphere in relation to traditional notions of civic discourse and democratic participation.\n\nHowever, there is no single definition or clear consensus on what constitutes the public sphere in the context of new media. The texts suggest that the public sphere has undergone significant transformations with the advent of digital technologies, and scholars are grappling with questions such as:\n\n* What forms does the public sphere take in online spaces?\n* How do digital technologies shape our understanding of civic discourse and democratic participation?\n* Can the internet be seen as a new public sphere, or is it something distinct from traditional notions of the public sphere?\n\nOverall, while the passage provides insight into the ongoing debates surrounding the concept of the public sphere, it does not offer a definitive definition.'),
#   Document(metadata={'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf', 'page': 3}, page_content='The text passage discusses the concept of the public sphere in relation to liberal-individualist digital democracy. The definition of the public sphere can be summarized as follows:\n\n* It refers to the opportunities afforded to individuals to have their particular interests realized through liberal political systems.\n* Digital media are seen as enabling individuals to effectively transmit information and viewpoints, register their choices, and aggregate public opinion.\n* This concept is advanced through various e-democracy initiatives, commercial sites, corporate media-politics sites, independent e-democracy projects, and civil society practices.\n* The democratic subject of this liberal-individualist position combines two aspects: an individual who knows their own best interests (rational, self-seeking) and a self that can empathize with and support the needs and rights of others.\n\nIn essence, the public sphere in this context is seen as a space where individuals can engage with politics and make their voices heard through digital media, enabling them to participate in decision-making processes and shape public opinion.'),
#   Document(metadata={'source': 'test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf', 'page': 57}, page_content='The text passage does not explicitly define the public sphere. However, it discusses the challenges to expertise and scientific authority in the context of a democratic public arena.\n\nThe author suggests that as economic models become more influential, they may constrain political options and lead to increased opposition from populist challengers and civil society groups. This opposition questions the legitimacy of experts and scientists, potentially threatening their authority and influence.\n\nThe passage implies that the public sphere is a space where science and expertise are subject to scrutiny and challenge, particularly in times of crisis or when scientific advice has significant implications for policy decisions. The author notes that this confrontation between science and democracy can be intense and may require experts to defend their epistemologies and conclusions in the public arena.\n\nOverall, while the passage does not provide a formal definition of the public sphere, it highlights its importance as a space where expertise is subject to democratic scrutiny and challenge.')],
#  'context': [Document(metadata={'page': 2, 'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf'}, page_content='Dahlberg 857\nthird element refers to the specific ways in which digital media is seen to be supporting \nthe development of the other two elements. I have chosen the term affordances as it \nbroadly captures how all the positions tend to understand the human–technology \nrelationship. In general terms, the relationship is one where the technology is seen to \nhave certain features that enable (afford) particular democratic uses and outcomes. 1 \nFinally, I explored how digital democracy commentary and practice was positioned in \nrelation to these three immanent, interrelated, and mutually effecting elements. This \nenabled me to reconstruct  a number of positions, including the four outlined in this \narticle.2 As interpretatively reconstructed representations of the articulations of empirical \ninstances, the resulting positions are open to (and indeed invite) challenge and rewriting \nin digital democracy scholarship. \nThe empirical material from which I reconstructed the four positions consists of a \ncombination of e-democracy commentary, academic research, and digital democracy \npractice. I do not specifically differentiate between ‘theoretical’ and ‘practical’ materials. I \nsee these as mutually implicated. Practices embody systems of ideas, and such systems are \nnot only themselves a form of practice but draw from practical experience. Moreover, given \nthe heterogeneous and ever-changing nature of this material – the ‘set’ of all to do with \ndigital democracy – ‘representative’ sampling was rejected. Rather, in accord with a critical-\ninterpretative approach, I drew upon my knowledge and previous research in the field to \nchoose what I considered exemplary digital democracy texts and practices. My choice of \nexemplars, as well as my subsequent reading, is necessarily marked by my subjective \nexperience and judgement, and given ongoing developments in the field invites rereading. \nI name the four reconstructed positions liberal-individualist, deliberative, counter-\npublics, and autonomist Marxist. My research indicates that these positions characterize \nwidely influential understandings in digital democracy rhetoric and practice. However, I do \nnot claim that they in any way exhaust the e-democracy positions that could be explicated. \nGiven more space and research resources we could identify and explore a number of other \ne-democracy articulations, including cyber-feminist (for example, Fernandez et al., 2004; \nFuller, 2004; Hall, 1996; Plant, 1996), communitarian (see Dahlberg, 2001a), cyber-liber-\ntarian (see Dahlberg, 2010), liberal digital commonism (for example, Benkler, 2006; Lessig, \n2001), and postmodern (for example, Nguyen and Alexander, 1996; Poster, 2001). It would \nalso be interesting to ask if distinct positions could be seen developing out of experiences \nof subalternity, particularly in relation to the Global South. In addition, we could outline \nmore cautious, and even dystopian, positions (see Kroker and Kroker, 1997; Kroker and \nWeinstein, 1994). Moreover, e-democracy would be characterized differently if we were to \nidentify, and deploy as organizing dimensions, elements immanent to rhetoric and practice \nother than the three used here (such as those listed above). However, I found the three \nelements deployed to be central in digital democracy articulations. While necessarily \nlimited in scope, I believe that the resulting outline brings much needed attention to digital \ndemocracy’s diversity and provides a framework for further research. \nLiberal-individualist digital democracy \nMuch digital democracy discussion and practice draws upon what I refer to as a liberal- \nindividualist understanding of democracy. I refer to this position as liberal-individualist '),
#   Document(metadata={'page': 10, 'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf'}, page_content='Dahlberg 865\nTable 2. Affordances in the four digital democracy positions\nDigital Democratic Affordances\nLiberal-consumer aggregating, calculating, choosing, competing, expressing, \nfundraising, informing, petitioning, registering, transacting, \ntransmitting, voting\nDeliberative agreeing, arguing, deliberating, disagreeing, informing, meeting, \nopinion forming, publicizing, reflecting\nCounter-publics articulating, associating, campaigning, contesting, forming groups, \nidentifying, organizing, protesting, resisting\nAutonomous Marxist collaborating, cooperating, distributing, exchanging, giving, \nnetworking, participating, sharing\nTable 1. Subject and democracy in the four digital democracy positions\nSubject Democracy\nLiberal-consumer self-sufficient, rational-strategic individual competitive-aggregative\nDeliberative inter-subjectively rational individual deliberative-consensual\nCounter-publics discursive-antagonistic individual/public contestationary\nAutonomous Marxist multitude of singularities commons networking\nin alphabetical order, as a summary of the democratic affordances that each position \nidentifies with digital media technology. These signifiers should not be taken as a hard or \nfinal defining of these positions, which are dynamic. Neither should the signifiers be \nseen as unique to each position. Rather, the list of signifiers in Table 2 represents a rough \nindication of each of the positions with respect to how they understand the democratic \naffordances of digital technology.\nWith respect to these affordances, I have not attempted to differentiate between how \npositions understand the relationship between human agency and technological effects. \nAn investigation of such a differentiation is complex and beyond the scope of this article. \nI will simply note that the rhetoric and practice from out of which the four positions were \nreconstructed assume an understanding somewhere along the spectrum between ‘uses’ \nand ‘constitution’ models of human–technology relations (see Dahlberg, 2004; Poster, \n2001). Sometimes the technology is understood more as a ‘tool’ for uses determined by \nindependent human agents, as in communication conduits or the means for engaging in \nactivism. At other times digital media are seen more constitutively, as bringing into being \nparticular spaces, objects, subjects, and practices. One general observation, however, can \nbe made. This is that the rhetoric and practice of the liberal-individualist position tends \nto read digital media as most tool-like (able to be developed and deployed at will by \nindividuals and groups to meet their needs and desires), while the autonomist position \ntakes the most constitutive understanding, seeing digital communication networks as \nbringing into existence a new democratic society. However, within all four positions we '),
#   Document(metadata={'page': 16, 'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf'}, page_content='Dahlberg 871\nHabermas J (1989) The Structural Transformation of the Public Sphere: An Inquiry into a Category \nof Bourgeois Society (trans. Thomas Burger). Cambridge, MA: MIT Press.\nHabermas J (1996) Between Facts and Norms: Contributions to a Discourse Theory of Law and \nDemocracy (trans. William Rehg). Cambridge, UK: Polity Press.\nHabermas J (2006) Political communication in media society: Does democracy still enjoy an \nepistemic dimension? The impact of normative theory on empirical research. Communication \nTheory 16(4): 411–426.\nHall K (1996) Cyberfeminism. In: Herring SC (ed.) Computer-mediated Communication: \nLinguistic, Social and Cross-cultural Perspectives. Amsterdam: John Benjamins, 147–170. \nHardt M and Negri A (2004) Multitude: War and Democracy in the Age of Empire . New York: \nPenguin.\nHardt M and Negri A (2009) Commonwealth. Cambridge, MA: Harvard University Press. \nHindman M (2009) The Myth of Digital Democracy. Princeton, NJ: Princeton University Press\nJanssen D and Kies R (2005) Online forums and deliberative democracy. Acta Politica 40(3): \n384–392.\nJohnston J and Laxer G (2003) Solidarity in the age of globalization: Lessons from the anti-MAI \nand Zapitista struggles. Theory and Society 32(1): 39–91.\nJordan T (2007) Online direct action: Hactivism and radical democracy. In: Dahlberg L and Siapera \nE (eds) Radical Democracy and the Internet. New York: Palgrave, 73–88.\nKahn R and Kellner D (2005) Oppositional politics and the internet: A critical/reconstructive \napproach Cultural Politics: An International Journal 1(1): 75–100.\nKahn R and Kellner D (2007) Globalization, technopolitics and radical democracy. In: Dahlberg L \nand Siapera E (eds) The Internet and Radical Democracy: Interrogating Theory and Practice. \nLondon: Palgrave, 17–36.\nKidd D (2003) Indymedia.org: A new communications commons. In: McCaughey M and Ayers \nMD (eds) Cyberactivism: Online Activism in Theory and Practice.  New York: Routledge, \n47–70.\nKowal D M (2002) Digitizing and globalizing indigenous voices: The Zapatista movement. In: \nElmer G (ed.) Critical Perspectives on the Internet . Lanham, MA: Rowman and Littlefield, \n105–126.\nKroker A and Kroker M (eds) (1997) Digital Delirium. New York: New World Perspectives.\nKroker A and Weinstein MA (1994) Data Trash: The Theory of the Virtual Class . New York: St \nMartin’s Press.\nLangman L (2005) From virtual public spheres to global justice: A critical theory of internet -\nworked social movements. Sociological Theory 23(1): 42–74.\nLessig L (2001) The Future of Ideas: The Fate of the Commons in a Connected World. New York: \nRandom House.\nLondon S (1995) Teledemocracy vs deliberative democracy: A comparative look at two models of \npublic talk. Journal of Interpersonal Computing and Technology 3(2): 33–35.\nMcDorman T F (2001) Crafting a virtual counterpublic: Right-to-die advocates on the internet. \nIn: Asen R and Brouwer DC (eds) Counterpublics and the State . Albany, NY: SUNY Press, \n187–210.\nMitra A (2004) V oices of the marginalized on the internet: Examples from a website for women of \nSouth Asia. International Journal of Communication 54(3): 492–510.\nMouffe C (2005) For an agonistic public sphere. In: Tønder L and Thomassen L (eds) Radical \nDemocracy: Politics Between Abundance and Lack . Manchester: University of Manchester \nPress, 123–132.\nNegri A (2008a) The Porcelain Workshop: For a New Grammar of Politics. New York: Semiotext(e).\nNegri A (2008b) Empire and Beyond. Cambridge, UK: Polity.'),
#   Document(metadata={'page': 15, 'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf'}, page_content='870 new media & society 13(6)\nDahlberg L (2004) Internet research tracings: Towards non-reductionist methodology. Journal of \nComputer-mediated Communications 9(3). Available at: http://jcmc.indiana.edu/vol9/issue3/\ndahlberg.html (consulted September 2010).\nDahlberg L (2007a) The Internet and discursive exclusion.  In: Dahlberg L and Siapera E (eds)  \nRadical Democracy and the Internet: Exploring Theory and Practice.  London: Palgrave,  \n128–147.\nDahlberg L (2007b) Rethinking the fragmentation of the cyber-public: From consensus to contes-\ntation. New Media & Society 9(5): 829–849.\nDahlberg L (2010) Cyber-libertarianism 2.0: A Discourse theory/critical political economy exami-\nnation. Cultural Politics 6(3): 331–356.\nDahlgren P (2007) Civic identity and net activism: The frame of radical democracy. In: Dahlberg L \nand Siapera E (eds) Radical Democracy and the Internet: Interrogating Theory and Practice. \nNew York: Palgrave, 55–72.\nDietz M (1992) Context is all, feminism and theories of citizenship. In: Mouffe C (ed.) Dimensions \nof Radical Democracy. London: Verso, 63–85.\nDowney J and Fenton N (2003) New media, counter publicity and the public sphere.  New Media \n& Society 5(2): 185–202.\nDyer-Witheford N (2002) The new combinations. The New Centennial Review 1(3): 155–200.\nDyer-Witheford N (2006) Species-being and the new commonism: Notes on an interrupted cycle \nof struggles. The Commoner 11(Spring): 15–32.\nDyer-Witheford N (2007) Hegemony or multitude? Two versions of radical democracy for the net. \nIn: Dahlberg L and Siapera E (eds), Radical Democracy and the Internet. New York: Palgrave, \n191–206.\nFang N-H (1995) The Internet as a public sphere: A Habermasian approach. Unpublished doctoral \ndissertation, State University of New York, Buffalo. \nFernandez M, Wilding F and Wright M (eds) (2004) Domain Errors! Cyberfeminist Practices . \nLondon: Pluto Press.\nFraser N (1992) Rethinking the public sphere: A contribution to the critique of actually existing \ndemocracy. In: Barker F, Hulme P and Iversen M (eds) Postmodernism and the Re-reading of \nModernity. Manchester: Manchester University Press, 197–231.\nFriedland LA, Hove T and Rojas H (2006) The networked public sphere. Javnost – the Public \n13(4): 5–26.\nFuller M (2004) Behind the Blip: Essays on the Culture of Software. London: Pluto Press.\nGallo J (2003) Online Oppositional Communities as Discursive Counterpublics. Paper presented \nat the Association of Internet Researchers Conference, Toronto, October.\nGibson JJ (1977) The theory of affordances. In: Shaw R and Bransford J (eds) Perceiving, Acting, \nand Knowing: Toward an Ecological Psychology. Hillsdale, NJ: Lawrence Erlbaum, 67–82.\nGillet J (2007) Internet web logs as cultural resistance: A case study of the SARS Arts Project. \nJournal of Communication Inquiry 31(1): 28–43.\nGimmler A (2001) Deliberative democracy, the public sphere and the internet. Philosophy and \nSocial Criticism 27(4): 21–39. \nGlynos J and Howarth D (2007) Logics of Critical Explanation in Social and Political Theory . \nLondon: Routledge. \nGore A (1994) The global information infrastructure: Forging a new Athenian age of democracy. \nIntermedia 22(2): 4–7. \nGraham T (2009) What’s wife swap got to do with it? Talking politics in the net-based public sphere. \nDoctoral Dissertation, University of Amsterdam, Amsterdam School of Communications.\nHabermas J (1984) The Theory of Communicative Action  (trans. Thomas McCarthy). (V ol. 1, \nReason and the Rationalization of Society). Boston, MA: Beacon Press.'),
#   Document(metadata={'page': 3, 'source': 'test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf'}, page_content='858 new media & society 13(6)\nbecause it focuses on the opportunities afforded to individuals to have their particular \ninterests realized through liberal political systems. I will briefly outline the democratic \naffordances offered by digital media that this position highlights, before identifying the \nassumed democratic subject and associated understanding of democracy. \nLiberal-individualist digital democracy understands digital media as offering a \nmeans for the effective transmission of information and viewpoints between individuals \nand representative decision-making processes (for example, Gore, 1994, in relation to \nthe early internet, and Chadwick, 2009, in relation to digital social networking develop-\nments). Digital media are understood here as enabling individuals to gain the informa -\ntion they need to examine competing political positions and problems, and as providing \nthem with the means for the registration, and subsequent aggregation (as ‘public opin -\nion’), of their choices (through e-voting, web feedback systems, petitions, e-mail, \nonline polls, etc.). \nThis liberal-individualist position is being advanced through a range of local and \nnational government e-democracy initiatives (see examples in Chadwick, 2009, and at \nSteven Clift’s site at http://www.publicus.net/), as well as through commercial sites (for \nexample, australianpolitics.com, speakout.com, vote.com), corporate media-politics \nsites (in particular, corporate news sites providing ‘public opinion’ polling and ‘have \nyour say’ comment systems), ‘independent’ e-democracy projects (for example, calvoter.\norg, mysociety.org, theglobalvote.org, votinginfoproject.org, vote-smart.org, 2gov.org), \nand civil society practices (for example, Amnesty International, Avaaz.org, Avaaz’s  \nparent Moveon.org, and Avaaz’s founding partner Getup!).  In the case of Amnesty \nInternational, the internet (text, audio, and video) and other digital media (cell phones \nand video cameras) are deployed as  tools through which liberty-interested individuals \ncan take action on exposed ‘rights’ violations around the world, transmitting information \non human rights abuses and providing the means to undertake individual actions (e-mailing \ngovernment officials, signing e-mail petitions, making electronic donations to appeals, \nparticipating in online polls, and filing membership applications). \nThis Amnesty case demonstrates how the international communication enabled by the \ninternet is being harnessed by certain organizations to extend liberal-individualist demo-\ncratic actions globally. Avaaz.org, for instance, looms as the largest campaigning organi-\nzation in history, if one measures size by numbers of individuals virtually participating \nin its campaigns. It uses e-mail and simple internet petitions to enable (and encourage) \nindividuals to add their names (if not voices) to those of others with the hope of bringing \nglobal ‘public opinion’ to bear on decision makers in relation to a wide range of interna-\ntional issues, including global warming, transnational military actions, ‘natural’ disaster \nrelief, and global economic management. \nThe democratic subject of this liberal-individualist position combines a couple of \naspects. First, it is understood to be an individual,  rational, self-seeking, instrumental \nutility maximizer who knows his/her own best interests. This self clearly reflects the \nclassic liberal economic agent found in Schumpeter (1976: 169), through which \n‘citizenship becomes less a collective, political activity than an individual, economic \nactivity – the right to pursue one’s interests, without hindrance, in the marketplace’ \n(Dietz, 1992: 67). However, room is also made for the self as, in a more Rawlsian vein, \nit is capable of empathizing with and supporting the needs and ‘rig ...
#   Document(metadata={'page': 57, 'source': 'test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf'}, page_content='those employed in heavily impacted sectors of the economy. The issue is not\nwhether economic models indicate the need for austerity policies, but if these\nmodels account for enough of human life or the boundaries of economic\nprotection as to be meaningful.\nThe opposition to experts is already a common feature among populist\nchallengers and other civil society challengers but it could spread more widely\nif these crises further increase reliance on expertise that constrain political\noptions, and media and professional institutions weaken. This opposition ques-\ntions the legitimacy of experts and scientists to limit the will of the people.\nOnce peoples’ options in exercising their occupations or personal freedoms\nbecome narrowed by the say-so of experts and scientists, people will challenge\ntheir legitimacy. This might not be true for a majority (Bertsou & Caramani\n2020), especially since the COVID-19 pandemic seems to have led to an\nincrease in popular trust in scientists. A heavily mobilized, highly intercon-\nnected critical minority might be enough, however, to mount an effective\nchallenge. One early example is the“Querdenker” (contrarian thinkers) move-\nment in Germany, a vocal and increasingly radicalized minority in Germany\nopposed to the government’s interventions to stop the spread of COVID-19,\nwhich attacks leading epidemiologists and sees scientists as being in the pocket\nof Big Pharma. When scientiﬁc epistemologies and expert advice increasingly\nset the agenda in a consensus-oriented public arena, their position in difﬁcult\ntimes is bound to be challenged. This atmosphere threatens to unearth the\ninherent potential conﬂict that emerges between science and democracy when\nan objective approach to understand and explain the world comes to be seen as\na “religion of an elite” (Lippman 1928: 39)– in this case a technocratic elite–\nand accordingly democratically rejected.\nThe structural tensions of public arenas described above force these conﬂicts\ninto the open. Just as politicians and journalists before them (Gurri 2018),\nscientists and experts canﬁnd their institutional standing or authority chal-\nlenged (Levin 2020) and must face their challengers in the public arena and\ndefend their epistemologies and conclusions. This is vital and justiﬁed if they\nexpect for their advice to limit the opportunities, choices, economic prospects,\nand personal freedoms if followed by governments.3 Western democratic insti-\ntutions especially may have to get used to the noise and heat of the contempor-\nary public arena instead of hoping to somehow turn back the clock to\na centralized and orderly public arena.\n3 This means also stepping away from fashionable relativistic posturing. It is notable here that even\nacademics in theﬁeld of science and technology studies, whose main stance has been to deny the\nobjectivity of science for several decades, now, in the face of climate change and the pandemic,\n52 Politics and Communication\nhttps://doi.org/10.1017/9781009064484\n Published online by Cambridge University Press')],
#  'answer': "Based on the summaries provided, I can offer some insights into the concept of the public sphere. However, please note that there is no single, definitive definition of the public sphere across all relevant texts.\n\nFrom Source: test_data\\Dahlberg 2011 Re-Constructing Digital Democracy.pdf:\n\n* The public sphere refers to a space where citizens engage in public discourse, debate, and discussion about issues affecting society.\n* It is often associated with the idea of a democratic public, where individuals can freely express their opinions, participate in deliberation, and hold those in power accountable.\n\nFrom Source: test_data\\Jungherr & Schroeder 2021 Digital Transformations of the Public Arena.pdf:\n\n* The public sphere is a space where science and expertise are subject to scrutiny and challenge, particularly in times of crisis or when scientific advice has significant implications for policy decisions.\n* It is a space where democratic values and processes are put into practice, allowing citizens to engage with politics and make their voices heard.\n\nFrom general knowledge:\n\n* The public sphere is often seen as a key component of democratic societies, allowing for the exchange of ideas and the formation of public opinion.\n* It can take various forms, including traditional civic discourse, online spaces such as social media platforms, blogs, and forums, and other digital environments.\n\nWhile these summaries provide some insight into the concept of the public sphere, it is essential to note that there is no single definition or clear consensus on what constitutes the public sphere in the context of new media. The texts suggest that the public sphere has undergone significant transformations with the advent of digital technologies, and scholars are grappling with questions such as:\n\n* What forms does the public sphere take in online spaces?\n* How do digital technologies shape our understanding of civic discourse and democratic participation?\n\nI don't know a definitive answer to your question about the definition of the public sphere."}

# %% [markdown]
# ## Self-Querying Retrieval

# %%
from langchain.chains.query_constructor.schema import AttributeInfo

metadata_field_info = [
    AttributeInfo(
        name = "author",
        description="The author of the paper",
        type="string",
    ),
    AttributeInfo(
        name = "year",
        description="The year of publication",
        type="string",
    ),
    AttributeInfo(
        name = "title",
        description="The title of the paper",
        type="string",
    ),
    AttributeInfo(
        name = "page",
        description="The page number of the paper",
        type="string",
    ),
    AttributeInfo(
        name = "source",
        description="The file path of the paper",
        type="string",
    ),
]

document_content_description = "A passage from a scientific paper"

# %%
from langchain.chains.query_constructor.base import get_query_constructor_prompt

retrieval_prompt = get_query_constructor_prompt( # we're using a premade prompt for the query constructor
    document_contents=document_content_description,
    attribute_info=metadata_field_info,
    # examples = retriever examples, # we can optionally add examples for the model to fine tune the retrieval. See https://github.com/langchain-ai/langchain/blob/master/cookbook/self_query_hotel_search.ipynb
)

print(retrieval_prompt.format(query="{query}")) # print out the prompt used for the query constructor
# Out:
# Your goal is to structure the user's query to match the request schema provided below.
#
# << Structured Request Schema >>
# When responding use a markdown code snippet with a JSON object formatted in the following schema:
#
# ```json
# {
#     "query": string \ text string to compare to document contents
#     "filter": string \ logical condition statement for filtering documents
# }
# ```
#
# The query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.
#
# A logical condition statement is composed of one or more comparison and logical operation statements.
#
# A comparison statement takes the form: `comp(attr, val)`:
# - `comp` (eq | ne | gt | gte | lt | lte | contain | like | in | nin): comparator
# - `attr` (string):  name of attribute to apply the comparison to
# - `val` (string): is the comparison value
#
# A logical operation statement takes the form `op(statement1, statement2, ...)`:
# - `op` (and | or | not): logical operator
# - `statement1`, `statement2`, ... (comparison statements or logical operation statements): one or more statements to apply the operation to
#
# Make sure that you only use the comparators and logical operators listed above and no others.
# Make sure that filters only refer to attributes that exist in the data source.
# Make sure that filters only use the attributed names with its function names if there are functions applied on them.
# Make sure that filters only use format `YYYY-MM-DD` when handling date data typed values.
# Make sure that filters take into account the descriptions of attributes and only make comparisons that are feasible given the type of data being stored.
# Make sure that filters are only used as needed. If there are no filters that should be applied return "NO_FILTER" for the filter value.
#
# << Example 1. >>
# Data Source:
# ```json
# {
#     "content": "Lyrics of a song",
#     "attributes": {
#         "artist": {
#             "type": "string",
#             "description": "Name of the song artist"
#         },
#         "length": {
#             "type": "integer",
#             "description": "Length of the song in seconds"
#         },
#         "genre": {
#             "type": "string",
#             "description": "The song genre, one of "pop", "rock" or "rap""
#         }
#     }
# }
# ```
#
# User Query:
# What are songs by Taylor Swift or Katy Perry about teenage romance under 3 minutes long in the dance pop genre
#
# Structured Request:
# ```json
# {
#     "query": "teenager love",
#     "filter": "and(or(eq(\"artist\", \"Taylor Swift\"), eq(\"artist\", \"Katy Perry\")), lt(\"length\", 180), eq(\"genre\", \"pop\"))"
# }
# ```
#
#
# << Example 2. >>
# Data Source:
# ```json
# {
#     "content": "Lyrics of a song",
#     "attributes": {
#         "artist": {
#             "type": "string",
#             "description": "Name of the song artist"
#         },
#         "length": {
#             "type": "integer",
#             "description": "Length of the song in seconds"
#         },
#         "genre": {
#             "type": "string",
#             "description": "The song genre, one of "pop", "rock" or "rap""
#         }
#     }
# }
# ```
#
# User Query:
# What are songs that were not published on Spotify
#
# Structured Request:
# ```json
# {
#     "query": "",
#     "filter": "NO_FILTER"
# }
# ```
#
#
# << Example 3. >>
# Data Source:
# ```json
# {
#     "content": "A passage from a scientific paper",
#     "attributes": {
#     "author": {
#         "description": "The author of the paper",
#         "type": "string"
#     },
#     "year": {
#         "description": "The year of publication",
#         "type": "string"
#     },
#     "title": {
#         "description": "The title of the paper",
#         "type": "string"
#     },
#     "page": {
#         "description": "The page number of the paper",
#         "type": "string"
#     },
#     "source": {
#         "description": "The file path of the paper",
#         "type": "string"
#     }
# }
# }
# ```
#
# User Query:
# {query}
#
# Structured Request:

# %%
from langchain.chains.query_constructor.base import StructuredQueryOutputParser

output_parser = StructuredQueryOutputParser.from_components( # we're also using a premade output parser
    fix_invalid=True, # this automatically fixes invalid queries (that is, it should avoid errors being thrown when the model constructs an invalid query)
    ) 

query_constructor = retrieval_prompt | llm | output_parser

query_constructor.invoke( # test if the query constructor works. Always do this when switching models, e.g. nemotron-mini does not handle the query constructor out of the box (same issues as with tools calls?)
    {
        "query": "What does Fraser say about the public sphere?",
    }
)
# Out:
# StructuredQuery(query='public sphere', filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='Fraser'), limit=None)

# %%
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_community.query_constructors.chroma import ChromaTranslator

retriever = SelfQueryRetriever(
    query_constructor=query_constructor,
    vectorstore=vector_store,
    structured_query_translator=ChromaTranslator(), # we need to specify the translator for our database scheme, e.g. Chroma
    search_type="mmr",
    search_kwargs={"k": docs_returned, # make sure the number of documents passed (k) fits into the context window
               "fetch_k": docs_returned * 5, # could be adjusted, potentially run tests
               "lambda_mult": 0.8 # amount of diversification, with 0 being maximum diversity
               }, 
)

# %%
retriever.invoke("What does Fraser say about the public sphere?")
# Out:
# [Document(metadata={'author': 'Fraser', 'page': 4, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='Nancy Fraser 59 \nThus, at one level, the idea of the public sphere designated an institu- \ntional mechanism for "rationalizing" political domination by rendering \nstates accountable to (some of) the citizenry. At another level, it desig- \nnated a specific kind of discursive interaction. Here the public sphere \nconnoted an ideal of unrestricted rational discussion of public matters. \nThe discussion was to be open and accessible to all; merely private \ninterests were to be inadmissible; inequalities of status were to be brack- \neted; and discussants were to deliberate as peers. The result of such \ndiscussion would be "public opinion" in the strong sense of a consensus \nabout the common good. \nAccording to Habermas, the full utopian potential of the bourgeois \nconception of the public sphere was never realized in practice. The claim \nto open access in particular was not made good. Moreover, the bourgeois \nconception of the public sphere was premised on a social order in which'),
#  Document(metadata={'author': 'Fraser', 'page': 23, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 5686, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='institutionalization of democratic interaction. Moreover, as Habermas has himself often pointed out, \neven in existing class societies, the significance of the public sphere is not entirely exhausted by its \nclass function. On the contrary, the idea of the public sphere also functions here and now as a normnn of \ndemocratic interaction we use to criticize the limitations of actually existing public spheres. The point \nThis content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM\nAll use subject to JSTOR Terms and Conditions'),
#  Document(metadata={'author': 'Fraser', 'page': 3, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 1634, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='scribes it, which this newer historiography renders suspect. Next, in the \nfollowing four sections, I shall examine each of these assumptions in turn. \nFinally, in a brief conclusion, I shall draw together some strands from \nthese critical discussions that point toward an alternative, post-bourgeois \nconception of the public sphere. \nThe public sphere: Alternative histories, competing conceptions \nLet me begin by sketching some highlights of Habermas\'s account of the \nstructural transformation of the public sphere. According to Habermas, \nthe idea of a public sphere is that of a body of "private persons" assem- \nbled to discuss matters of "public concern" or "common interest." This \nidea acquired force and reality in early modern Europe in the constitution \nof "bourgeois publics spheres" as counterweights to absolutist states. \nThese publics aimed to mediate between "society" and the state by hold- \ning the state accountable to "society" via "publicity." At first this meant'),
#  Document(metadata={'author': 'Fraser', 'page': 21, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='76 Rethinking the Public Sphere \nplaces, child care centers, or residential communities, for example, inter- \nnal institutional public spheres could be arenas both of opinion formation \nand decision-making. This would be tantamount to constituting sites of \ndirect or quasi-direct democracy wherein all those engaged in a collective \nundertaking would participate in deliberations to determine its design and \noperation." However, this would still leave open the relationship between \nsuch internal public spheres-cum-decision-making-bodies and those ex- \nternal publics to which they might also be deemed accountable. The \nquestion of that relationship becomes important when we consider that \npeople who are affected by an undertaking in which they do not directly \nparticipate as agents may nonetheless have a stake in its modus operandi; \nthey therefore also have a legitimate claim to a say, through some other \n(weaker or stronger) public sphere, in its institutional design and opera- \ntion.'),
#  Document(metadata={'author': 'Fraser', 'page': 15, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 2435, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='One important object of such interpublic contestation is the appropriate \nboundaries of the public sphere. Here the central questions are, what \ncounts as a public matter and what, in contrast, is private? This brings me \nto a third set of problematic assumptions underlying the bourgeois con- \nception of the public sphere, namely, assumptions concerning the appro- \npriate scope of publicity in relation to privacy. \nLet me remind you that it is central to Habermas\'s account that the \nbourgeois public sphere was to be a discursive arena in which "private \npersons" deliberated about "public matters." There are several different \nThis content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM\nAll use subject to JSTOR Terms and Conditions'),
#  Document(metadata={'author': 'Fraser', 'page': 19, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='74 Rethinking the Public Sphere \nnomic privacy and domestic privacy that delimit the scope of debate. \nThese notions, therefore, are vehicles through which gender and class \ndisadvantages may continue to operate subtextually and informally, even \nafter explicit, formal restrictions have been rescinded. \nStrong publics, weak publics: On civil society and the state \nLet me turn now to my fourth and last assumption underlying the bour- \ngeois conception of the public sphere, namely, the assumption that a \nfunctioning democratic public sphere requires a sharp separation of civil \nsociety and the state. This assumption is susceptible to two different \ninterpretations, depending on how one understands the expression "civil \nsociety." If one takes that expression to mean a privately-ordered, capi- \ntalist economy, then to insist on its separation from the state is to defend \nclassical liberalism. The claim would be that a system of limited govern-')]

# %%
retriever.invoke("What is the definition of the public sphere?")
# Out:
# [Document(metadata={'author': 'Fraser', 'page': 4, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='Nancy Fraser 59 \nThus, at one level, the idea of the public sphere designated an institu- \ntional mechanism for "rationalizing" political domination by rendering \nstates accountable to (some of) the citizenry. At another level, it desig- \nnated a specific kind of discursive interaction. Here the public sphere \nconnoted an ideal of unrestricted rational discussion of public matters. \nThe discussion was to be open and accessible to all; merely private \ninterests were to be inadmissible; inequalities of status were to be brack- \neted; and discussants were to deliberate as peers. The result of such \ndiscussion would be "public opinion" in the strong sense of a consensus \nabout the common good. \nAccording to Habermas, the full utopian potential of the bourgeois \nconception of the public sphere was never realized in practice. The claim \nto open access in particular was not made good. Moreover, the bourgeois \nconception of the public sphere was premised on a social order in which'),
#  Document(metadata={'author': 'Fraser', 'page': 23, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 5686, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='institutionalization of democratic interaction. Moreover, as Habermas has himself often pointed out, \neven in existing class societies, the significance of the public sphere is not entirely exhausted by its \nclass function. On the contrary, the idea of the public sphere also functions here and now as a normnn of \ndemocratic interaction we use to criticize the limitations of actually existing public spheres. The point \nThis content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM\nAll use subject to JSTOR Terms and Conditions'),
#  Document(metadata={'author': 'Fraser', 'page': 3, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 1634, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='scribes it, which this newer historiography renders suspect. Next, in the \nfollowing four sections, I shall examine each of these assumptions in turn. \nFinally, in a brief conclusion, I shall draw together some strands from \nthese critical discussions that point toward an alternative, post-bourgeois \nconception of the public sphere. \nThe public sphere: Alternative histories, competing conceptions \nLet me begin by sketching some highlights of Habermas\'s account of the \nstructural transformation of the public sphere. According to Habermas, \nthe idea of a public sphere is that of a body of "private persons" assem- \nbled to discuss matters of "public concern" or "common interest." This \nidea acquired force and reality in early modern Europe in the constitution \nof "bourgeois publics spheres" as counterweights to absolutist states. \nThese publics aimed to mediate between "society" and the state by hold- \ning the state accountable to "society" via "publicity." At first this meant'),
#  Document(metadata={'author': 'Fraser', 'page': 21, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='76 Rethinking the Public Sphere \nplaces, child care centers, or residential communities, for example, inter- \nnal institutional public spheres could be arenas both of opinion formation \nand decision-making. This would be tantamount to constituting sites of \ndirect or quasi-direct democracy wherein all those engaged in a collective \nundertaking would participate in deliberations to determine its design and \noperation." However, this would still leave open the relationship between \nsuch internal public spheres-cum-decision-making-bodies and those ex- \nternal publics to which they might also be deemed accountable. The \nquestion of that relationship becomes important when we consider that \npeople who are affected by an undertaking in which they do not directly \nparticipate as agents may nonetheless have a stake in its modus operandi; \nthey therefore also have a legitimate claim to a say, through some other \n(weaker or stronger) public sphere, in its institutional design and opera- \ntion.'),
#  Document(metadata={'author': 'Fraser', 'page': 15, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 2435, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='One important object of such interpublic contestation is the appropriate \nboundaries of the public sphere. Here the central questions are, what \ncounts as a public matter and what, in contrast, is private? This brings me \nto a third set of problematic assumptions underlying the bourgeois con- \nception of the public sphere, namely, assumptions concerning the appro- \npriate scope of publicity in relation to privacy. \nLet me remind you that it is central to Habermas\'s account that the \nbourgeois public sphere was to be a discursive arena in which "private \npersons" deliberated about "public matters." There are several different \nThis content downloaded from 138.87.151.140 on Wed, 9 Oct 2013 17:51:08 PM\nAll use subject to JSTOR Terms and Conditions'),
#  Document(metadata={'author': 'Fraser', 'page': 19, 'source': 'test_data\\Fraser 1990 Rethinking the Public Sphere.pdf', 'start_index': 0, 'title': 'Rethinking the Public Sphere', 'year': '1990'}, page_content='74 Rethinking the Public Sphere \nnomic privacy and domestic privacy that delimit the scope of debate. \nThese notions, therefore, are vehicles through which gender and class \ndisadvantages may continue to operate subtextually and informally, even \nafter explicit, formal restrictions have been rescinded. \nStrong publics, weak publics: On civil society and the state \nLet me turn now to my fourth and last assumption underlying the bour- \ngeois conception of the public sphere, namely, the assumption that a \nfunctioning democratic public sphere requires a sharp separation of civil \nsociety and the state. This assumption is susceptible to two different \ninterpretations, depending on how one understands the expression "civil \nsociety." If one takes that expression to mean a privately-ordered, capi- \ntalist economy, then to insist on its separation from the state is to defend \nclassical liberalism. The claim would be that a system of limited govern-')]

# %%
query_constructor.invoke("What is the definition of the public sphere?")
# Out:
# StructuredQuery(query='public sphere', filter=None, limit=None)

# %%
query_constructor.invoke("What does Nancy Fraser say about the public sphere?") # note that llama3.2 and Phi4 pass the full name, failing to get any results, as the documents are named with only the last name. 
                                                                                #   Additionally, Phi4 passes 'Nancy Fraser public sphere' as query in addition to the filter value "Nancy Fraser", thus bleeding the filter value into the query
# Out:
# StructuredQuery(query='Nancy Fraser public sphere', filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='Nancy Fraser'), limit=None)

# %% [markdown]
# The query constructor seems to do an okay job with passing structured queries. Note that this may be model dependant!

# %% [markdown]
# _to do_:
# - get more robustness when passing full names, e.g. "Nancy Fraser" should only query "Fraser" as author
